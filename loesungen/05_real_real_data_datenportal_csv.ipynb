# %% [markdown]
# # Zähme die Tabellen des Grauens

# %% [markdown]
# Lächle und sei froh, es könnte noch schlimmer kommen. Und ich lächelte und war froh ... und es kam schlimmer.
#
# Die Destatis-Flat-Tables sind im Vergleich zu anderen Datenportalen schon ganz gut.
# Das geht geht auch schlimmer:

# %% [markdown]
# Wir zeigen dir jetzt einmal das Datenportal [regionalstatistik.de](https://www.regionalstatistik.de/genesis/online/)

# %% [markdown]
# Ziel ist eine Choroplethen-Karte wie diese:

# %%
# Display the associated webpage in a new window
import IPython
IPython.display.IFrame('https://datawrapper.dwcdn.net/IJwst/4/', width='600', height='750')
# Out:
#         <iframe
#             width="600"
#             height="750"
#             src="https://datawrapper.dwcdn.net/IJwst/4/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### 1. Daten als .csv herunterladen

# %% [markdown]
# Suche auf regionalstatistik.de nach ‘Bauland’ oder direkt nach der Nummer der Tabelle: 61511-01-03-4. Lade die Daten als .csv herunter und speichere sie im ./data Ordner ab.

# %% [markdown]
# ### 2. Tabelle anschauen

# %% [markdown]
# Der erste Fehler fällt dir schon auf, wenn du versuchst, die Tabelle im Jupyter Notebook anzuklicken.
#
# Du bekommst folgende Fehlermeldung:
#
# ```"File Load Error for 61511-01-03-4.csv
# /home/p3nny/pfv/data/61511-01-03-4.csv is not UTF-8 encoded"
# ```
#
# Das heißt, der Zeichensatz, mit dem das Dokument angelegt ist, entspricht nicht dem Standard utf-8 sondern es wird ein deutsches Sonderformat verwendet.
#
# Öffne die .csv bitte mal in Excel oder Google Spreadsheets etc.
#
# Vor Dir siehst du eine recht verschachtelte Tabelle. Sie ist gut geeignet, um auf DIN-A4-Seiten ausgedruckt zu werden, Pandas oder ein Visualisierungstool wie Datawrapper ist damit jedoch überfordert.

# %% [markdown]
# ### 3. In pandas einlesen

# %% [markdown]
# Versuche mal die Tabelle per read_csv in Pandas einzulesen. Denke daran, dass du pandas erst einmal importieren musst.

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/61511-01-03-4.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-77282fc1aa32> in <module>
# ----> 1 df = pd.read_csv("./data/61511-01-03-4.csv")
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 4 fields in line 27, saw 5

# %% [markdown]
# Das wird nicht einfach, aber es geht. Allerdings musst du pandas an vielen Stellen auf die Sprünge helfen.

# %%
df = pd.read_csv('./data/61511-01-03-4.csv', sep=';', encoding='ISO-8859-1', skiprows=7, 
                 skipfooter=4, engine="python",
                 decimal=',',
                names=['Jahr', 'AGS', 'Ort', 'Art', 'Einheit', 'Insgesamt', 'baureifes Land'],
                dtype={'AGS': 'str'})

# %% [markdown]
# Hier kommt die Schritt für Schritt Erklärung:
#
# sep=';'
# In Deutschland wird anders als in den USA nicht das Komma als Trenner verwendet (das ist ja bereits belegt, weil wir '3,3' statt '3.3' schreiben), sondern der Trenner ist ein Semikolon ';'.
#
# encoding='ISO-8859-1'
# Setzt das zeichenformat auf 'ISO-8859-1', eine andere oft von deutschen Behörden genutzte Variante ist 'latin-1'. Welches verwendet wurde, weiß man vorher nicht. Deshalb müsst ihr die durchprobieren, falls utf-8 nicht geht.
#
# skiprows=7
# Überspringt den verschachtelten Tabellenkopf. Wie viele Zeilen du überspringen musst, ist von .csv zu .csv unterschiedlich. Auch hier hilft nur ausprobieren.
#
# skipfooter=4, engine="python"
# Skipfooter lässt Zeilen unten weg, die nicht zur Tabelle gehören. Diese Funktion erfordert die Angabe engine="python", sonst gibt es eine Fehlermeldung.
#
# decimal=','
# Gibt an, dass Python ',' als '.' bei Kommazahlen interpretieren soll: '3.2' statt '3.3'
#
# Damit lässt sich die Tabelle bereits einlesen. Hilfreich sind diese noch diese beiden Parameter:
#
# names=['Jahr', 'AGS', 'Ort', 'Art', 'Einheit', 'Insgesamt', 'baureifes Land']
# Gibt an, wie die Spalten heißen sollen
#
# dtype={'AGS': 'str'}
# Gibt schon beim einlesen an, dass der AGS als String eingelesen werden soll. Wenn der als Zahl erkannt wird, dann geht die führende Null verloren.

# %%
df
# Out:
#       Jahr    AGS                            Ort  \
# 0     2018     DG                    Deutschland
# 1     2018     DG                    Deutschland
# 2     2018     DG                    Deutschland
# 3     2018     DG                    Deutschland
# 4     2018     01             Schleswig-Holstein
# ...    ...    ...                            ...
# 2147  2018  16076                   Greiz, Kreis
# 2148  2018  16077        Altenburger Land, Kreis
# 2149  2018  16077        Altenburger Land, Kreis
# 2150  2018  16077        Altenburger Land, Kreis
# 2151  2018  16077        Altenburger Land, Kreis
#
#                                     Art   Einheit Insgesamt baureifes Land
# 0         Veräußerungsfälle von Bauland    Anzahl     84272          74692
# 1              Veräußerte Baulandfläche   1000 qm    130011          77147
# 2                             Kaufsumme  Tsd. EUR  17898272       14574917
# 3     Durchschnittlicher Kaufwert je qm       EUR    137.67         188.92
# 4         Veräußerungsfälle von Bauland    Anzahl      2003           1760
# ...                                 ...       ...       ...            ...
# 2147  Durchschnittlicher Kaufwert je qm       EUR     20.88          25.26
# 2148      Veräußerungsfälle von Bauland    Anzahl       121            111
# 2149           Veräußerte Baulandfläche   1000 qm       179             75
# 2150                          Kaufsumme  Tsd. EUR      3059           1814
# 2151  Durchschnittlicher Kaufwert je qm       EUR     17.07          24.20
#
# [2152 rows x 7 columns]

# %% [markdown]
# ### 3. Entscheiden, was visualisiert werden soll

# %% [markdown]
# Um eine Flächenwert-Stufen-Karte (Choroplethenkarte) zu erstellen, musst du zwei Entscheidungen treffen:
#
# - Welche regionale Ebene möchtest du darstellen? In diesem Fall möchten wir Kreise in Nordrhein-Westfalen zeigen.
# - Nach welchem Merkmal soll die Karte eingefärbt werden? Um Vergleichbarkeit herzustellen, möchten wir die Kreise anhand des durchschnittlichen Kaufwert je qm einfärben.

# %% [markdown]
# ### 4. Filtern auf 'durchschnittlicher Kaufwert je qm'

# %%
df = df[df['Art'] == 'Durchschnittlicher Kaufwert je qm']

# %%
df
# Out:
#       Jahr    AGS                                             Ort  \
# 3     2018     DG                                     Deutschland
# 7     2018     01                              Schleswig-Holstein
# 11    2018  01001                     Flensburg, Kreisfreie Stadt
# 15    2018  01002        Kiel, Landeshauptstadt, Kreisfreie Stadt
# 19    2018  01003            Lübeck, Hansestadt, Kreisfreie Stadt
# ...    ...    ...                                             ...
# 2135  2018  16073                      Saalfeld-Rudolstadt, Kreis
# 2139  2018  16074                            Saale-Holzland-Kreis
# 2143  2018  16075                                Saale-Orla-Kreis
# 2147  2018  16076                                    Greiz, Kreis
# 2151  2018  16077                         Altenburger Land, Kreis
#
#                                     Art Einheit Insgesamt baureifes Land
# 3     Durchschnittlicher Kaufwert je qm     EUR    137.67         188.92
# 7     Durchschnittlicher Kaufwert je qm     EUR     85.30         120.26
# 11    Durchschnittlicher Kaufwert je qm     EUR         .              .
# 15    Durchschnittlicher Kaufwert je qm     EUR         .              .
# 19    Durchschnittlicher Kaufwert je qm     EUR    110.84         144.06
# ...                                 ...     ...       ...            ...
# 2135  Durchschnittlicher Kaufwert je qm     EUR     42.50          41.80
# 2139  Durchschnittlicher Kaufwert je qm     EUR     44.25          49.51
# 2143  Durchschnittlicher Kaufwert je qm     EUR     24.05          25.66
# 2147  Durchschnittlicher Kaufwert je qm     EUR     20.88          25.26
# 2151  Durchschnittlicher Kaufwert je qm     EUR     17.07          24.20
#
# [538 rows x 7 columns]

# %% [markdown]
# ### 5. Filtern nach dem Allgemeinen Gemeindeschlüssel, AGS

# %% [markdown]
# Der amtliche Gemeindeschlüssel (AGS) ist eigentlich eine achtstellige Zahl, die alle Städte und politisch eigenständigen Gemeinden in Deutschland eindeutig identifiziert.
# In unserer Tabelle haben wir Daten bis runter auf Kreisebene, deshalb sind die ersten fünf Stellen angegeben.
# Wir interessieren uns nur für NRW, dessen Gemeindeschlüssel beginnen immer mit 05.
#
# [Hier wird der AGS interaktiv erklärt](https://datengui.de/statistik-erklaert/ags)

# %%
df = df[df.AGS.str.startswith('05')]

# %%
df
# Out:
#      Jahr    AGS                                 Ort  \
# 299  2018     05                 Nordrhein-Westfalen
# 303  2018    051        Düsseldorf, Regierungsbezirk
# 307  2018  05111        Düsseldorf, Kreisfreie Stadt
# 311  2018  05112          Duisburg, Kreisfreie Stadt
# 315  2018  05113             Essen, Kreisfreie Stadt
# ..    ...    ...                                 ...
# 523  2018  05962                    Märkischer Kreis
# 527  2018  05966                         Olpe, Kreis
# 531  2018  05970          Siegen-Wittgenstein, Kreis
# 535  2018  05974                        Soest, Kreis
# 539  2018  05978                         Unna, Kreis
#
#                                    Art Einheit Insgesamt baureifes Land
# 299  Durchschnittlicher Kaufwert je qm     EUR     99.49         137.71
# 303  Durchschnittlicher Kaufwert je qm     EUR    101.67         191.65
# 307  Durchschnittlicher Kaufwert je qm     EUR    959.98         959.98
# 311  Durchschnittlicher Kaufwert je qm     EUR    254.82         277.14
# 315  Durchschnittlicher Kaufwert je qm     EUR    274.93         322.64
# ..                                 ...     ...       ...            ...
# 523  Durchschnittlicher Kaufwert je qm     EUR     47.72          47.79
# 527  Durchschnittlicher Kaufwert je qm     EUR     91.93          91.93
# 531  Durchschnittlicher Kaufwert je qm     EUR     91.23          94.47
# 535  Durchschnittlicher Kaufwert je qm     EUR     74.75         106.72
# 539  Durchschnittlicher Kaufwert je qm     EUR    107.67         125.63
#
# [61 rows x 7 columns]

# %% [markdown]
# Leider haben wir in der Tabelle gemischte Werte für das gesamte Bundesland (AGS: 05), für die Regierungsbezirke (AGS zum Beispiel: 051) und für die Kreise (AGS zum Beispiel: 05111).
# So können wir die Daten nicht in Datawrapper packen, der erwartet auf einer Kreis-Karte nur Landkreise.
# Deshalb brauchen wir einen Trick, um alle Zeilen rauszufiltern, bei denen der AGS weniger als 5 Stellen hat:

# %% [markdown]
# Ein Weg ist für jeden Wert in der Spalte AGS zu gucken, ob die Länge des Strings größer als 3 ist. Erinnert ihr euch an die len('penny) Funktion?

# %%
def check_if_larger_than_3(x):
    if len(x) > 3:
        return True
    else:
        return False

# %% [markdown]
# Diese Funktion müssen wir dann auf alle Werte in der Spalte AGS anwenden. Dort wird dann entweder 'False' oder 'True' ausgegeben.

# %%
df.AGS.apply(check_if_larger_than_3)
# Out:
# 299    False
# 303    False
# 307     True
# 311     True
# 315     True
#        ...
# 523     True
# 527     True
# 531     True
# 535     True
# 539     True
# Name: AGS, Length: 61, dtype: bool

# %% [markdown]
# Pandas kann eine solche Funktion nutzen, um den Dataframe zu filtern:

# %%
df[df.AGS.apply(check_if_larger_than_3)].head()
# Out:
#      Jahr    AGS                                      Ort  \
# 307  2018  05111             Düsseldorf, Kreisfreie Stadt
# 311  2018  05112               Duisburg, Kreisfreie Stadt
# 315  2018  05113                  Essen, Kreisfreie Stadt
# 319  2018  05114                Krefeld, Kreisfreie Stadt
# 323  2018  05116        Mönchengladbach, Kreisfreie Stadt
#
#                                    Art Einheit Insgesamt baureifes Land
# 307  Durchschnittlicher Kaufwert je qm     EUR    959.98         959.98
# 311  Durchschnittlicher Kaufwert je qm     EUR    254.82         277.14
# 315  Durchschnittlicher Kaufwert je qm     EUR    274.93         322.64
# 319  Durchschnittlicher Kaufwert je qm     EUR     52.63         146.35
# 323  Durchschnittlicher Kaufwert je qm     EUR     85.40         128.48

# %% [markdown]
# Um Schreibarbeit zu sparen, nutzt man in der Datenanalyse einen kürzeren Weg, um die Funktion zu definiieren. Dann sieht das Ganze so aus:

# %%
df = df[df['AGS'].apply(lambda x: len(x)>3)]
df
# Out:
#      Jahr       AGS                                                Ort  \
# 307  2018     05111                       Düsseldorf, Kreisfreie Stadt
# 311  2018     05112                         Duisburg, Kreisfreie Stadt
# 315  2018     05113                            Essen, Kreisfreie Stadt
# 319  2018     05114                          Krefeld, Kreisfreie Stadt
# 323  2018     05116                  Mönchengladbach, Kreisfreie Stadt
# 327  2018     05117              Mülheim an der Ruhr, Kreisfreie Stadt
# 331  2018     05119                       Oberhausen, Kreisfreie Stadt
# 335  2018     05120                        Remscheid, Kreisfreie Stadt
# 339  2018     05122                         Solingen, Kreisfreie Stadt
# 343  2018     05124                        Wuppertal, Kreisfreie Stadt
# 347  2018     05154                                       Kleve, Kreis
# 351  2018     05158                                    Mettmann, Kreis
# %% [markdown]
# Das sieht schon ganz gut aus.
# Aber ist dir Aachen aufgefallen?

# %%
df[df.Ort.str.contains('Aachen')]
# Out:
#      Jahr       AGS                                                Ort  \
# 383  2018     05334        Städteregion Aachen (einschl. Stadt Aachen)
# 387  2018  05334002                                Aachen, krfr. Stadt
# 391  2018     05354                                      Aachen, Kreis
#
#                                    Art Einheit Insgesamt baureifes Land
# 383  Durchschnittlicher Kaufwert je qm     EUR    109.75         107.07
# 387  Durchschnittlicher Kaufwert je qm     EUR    158.97         157.82
# 391  Durchschnittlicher Kaufwert je qm     EUR         -              -

# %% [markdown]
# Aus Gründen wird Aachen in der Regionalstatistik oft mehrfach angegeben.
# Wir filtern die kreisfreie Stadt und den Kreis Aachen raus.

# %%
df = df[(df.AGS != '05354') & (df.AGS != '05334002') ]

# %%
df
# Out:
#      Jahr    AGS                                                Ort  \
# 307  2018  05111                       Düsseldorf, Kreisfreie Stadt
# 311  2018  05112                         Duisburg, Kreisfreie Stadt
# 315  2018  05113                            Essen, Kreisfreie Stadt
# 319  2018  05114                          Krefeld, Kreisfreie Stadt
# 323  2018  05116                  Mönchengladbach, Kreisfreie Stadt
# 327  2018  05117              Mülheim an der Ruhr, Kreisfreie Stadt
# 331  2018  05119                       Oberhausen, Kreisfreie Stadt
# 335  2018  05120                        Remscheid, Kreisfreie Stadt
# 339  2018  05122                         Solingen, Kreisfreie Stadt
# 343  2018  05124                        Wuppertal, Kreisfreie Stadt
# 347  2018  05154                                       Kleve, Kreis
# 351  2018  05158                                    Mettmann, Kreis
# 355  2018  05162                                  Rhein-Kreis Neuss
# 359  2018  05166                                     Viersen, Kreis
# 363  2018  05170                                       Wesel, Kreis
# 371  2018  05314                             Bonn, Kreisfreie Stadt
# 375  2018  05315                             Köln, Kreisfreie Stadt
# 379  2018  05316                       Leverkusen, Kreisfreie Stadt
# 383  2018  05334        Städteregion Aachen (einschl. Stadt Aachen)
# 395  2018  05358                                       Düren, Kreis
# 399  2018  05362                                   Rhein-Erft-Kreis
# 403  2018  05366                                  Euskirchen, Kreis
# 407  2018  05370                                   Heinsberg, Kreis
# 411  2018  05374                               Oberbergischer Kreis
# 415  2018  05378                         Rheinisch-Bergischer Kreis
# 419  2018  05382                                   Rhein-Sieg-Kreis
# 427  2018  05512                          Bottrop, Kreisfreie Stadt
# 431  2018  05513                    Gelsenkirchen, Kreisfreie Stadt
# 435  2018  05515                          Münster, Kreisfreie Stadt
# 439  2018  05554                                      Borken, Kreis
# 443  2018  05558                                    Coesfeld, Kreis
# 447  2018  05562                              Recklinghausen, Kreis
# 451  2018  05566                                   Steinfurt, Kreis
# 455  2018  05570                                   Warendorf, Kreis
# 463  2018  05711                        Bielefeld, Kreisfreie Stadt
# 467  2018  05754                                   Gütersloh, Kreis
# 471  2018  05758                                     Herford, Kreis
# 475  2018  05762                                      Höxter, Kreis
# 479  2018  05766                                       Lippe, Kreis
# 483  2018  05770                             Minden-Lübbecke, Kreis
# 487  2018  05774                                   Paderborn, Kreis
# 495  2018  05911                           Bochum, Kreisfreie Stadt
# 499  2018  05913                         Dortmund, Kreisfreie Stadt
# 503  2018  05914                            Hagen, Kreisfreie Stadt
# 507  2018  05915                             Hamm, Kreisfreie Stadt
# 511  2018  05916                            Herne, Kreisfreie Stadt
# 515  2018  05954                                  Ennepe-Ruhr-Kreis
# 519  2018  05958                                 Hochsauerlandkreis
# 523  2018  05962                                   Märkischer Kreis
# 527  2018  05966                                        Olpe, Kreis
# 531  2018  05970                         Siegen-Wittgenstein, Kreis
# 535  2018  05974                                       Soest, Kreis
# 539  2018  05978                                        Unna, Kreis
#
#                                    Art Einheit Insgesamt baureifes Land
# 307  Durchschnittlicher Kaufwert je qm     EUR    959.98         959.98
# 311  Durchschnittlicher Kaufwert je qm     EUR    254.82         277.14
# 315  Durchschnittlicher Kaufwert je qm     EUR    274.93         322.64
# 319  Durchschnittlicher Kaufwert je qm     EUR     52.63         146.35
# 323  Durchschnittlicher Kaufwert je qm     EUR     85.40         128.48
# 327  Durchschnittlicher Kaufwert je qm     EUR    239.44         239.44
# 331  Durchschnittlicher Kaufwert je qm     EUR    214.06         236.46
# 335  Durchschnittlicher Kaufwert je qm     EUR    117.16         125.64
# 339  Durchschnittlicher Kaufwert je qm     EUR    228.69         228.69
# 343  Durchschnittlicher Kaufwert je qm     EUR    132.95         160.85
# 347  Durchschnittlicher Kaufwert je qm     EUR     68.54         108.23
# 351  Durchschnittlicher Kaufwert je qm     EUR    245.65         339.09
# 355  Durchschnittlicher Kaufwert je qm     EUR    265.75         303.13
# 359  Durchschnittlicher Kaufwert je qm     EUR     74.01         167.94
# 363  Durchschnittlicher Kaufwert je qm     EUR    212.16         249.44
# 371  Durchschnittlicher Kaufwert je qm     EUR    321.87         323.26
# 375  Durchschnittlicher Kaufwert je qm     EUR    419.41         625.36
# 379  Durchschnittlicher Kaufwert je qm     EUR    314.50         314.50
# 383  Durchschnittlicher Kaufwert je qm     EUR    109.75         107.07
# 395  Durchschnittlicher Kaufwert je qm     EUR    120.36         120.56
# 399  Durchschnittlicher Kaufwert je qm     EUR    120.72         243.03
# 403  Durchschnittlicher Kaufwert je qm     EUR     76.84          77.04
# 407  Durchschnittlicher Kaufwert je qm     EUR    100.65         116.51
# 411  Durchschnittlicher Kaufwert je qm     EUR     81.91          84.09
# 415  Durchschnittlicher Kaufwert je qm     EUR    196.38         206.07
# 419  Durchschnittlicher Kaufwert je qm     EUR    208.61         223.55
# 427  Durchschnittlicher Kaufwert je qm     EUR    158.39         165.49
# 431  Durchschnittlicher Kaufwert je qm     EUR    109.44         186.86
# 435  Durchschnittlicher Kaufwert je qm     EUR    294.45         327.25
# 439  Durchschnittlicher Kaufwert je qm     EUR     56.53          97.61
# 443  Durchschnittlicher Kaufwert je qm     EUR    159.15         170.59
# 447  Durchschnittlicher Kaufwert je qm     EUR     74.40         161.19
# 451  Durchschnittlicher Kaufwert je qm     EUR    105.72         130.03
# 455  Durchschnittlicher Kaufwert je qm     EUR    141.77         155.08
# 463  Durchschnittlicher Kaufwert je qm     EUR    225.68         245.33
# 467  Durchschnittlicher Kaufwert je qm     EUR     92.13         100.30
# 471  Durchschnittlicher Kaufwert je qm     EUR     67.21          90.11
# 475  Durchschnittlicher Kaufwert je qm     EUR     40.86          48.22
# 479  Durchschnittlicher Kaufwert je qm     EUR    101.75         106.76
# 483  Durchschnittlicher Kaufwert je qm     EUR     62.94          80.35
# 487  Durchschnittlicher Kaufwert je qm     EUR    168.19         195.54
# 495  Durchschnittlicher Kaufwert je qm     EUR    107.37         163.59
# 499  Durchschnittlicher Kaufwert je qm     EUR    167.69         241.57
# 503  Durchschnittlicher Kaufwert je qm     EUR    102.48         103.84
# 507  Durchschnittlicher Kaufwert je qm     EUR    198.16         234.44
# 511  Durchschnittlicher Kaufwert je qm     EUR     94.55         228.79
# 515  Durchschnittlicher Kaufwert je qm     EUR    195.86         214.54
# 519  Durchschnittlicher Kaufwert je qm     EUR     48.19          59.30
# 523  Durchschnittlicher Kaufwert je qm     EUR     47.72          47.79
# 527  Durchschnittlicher Kaufwert je qm     EUR     91.93          91.93
# 531  Durchschnittlicher Kaufwert je qm     EUR     91.23          94.47
# 535  Durchschnittlicher Kaufwert je qm     EUR     74.75         106.72
# 539  Durchschnittlicher Kaufwert je qm     EUR    107.67         125.63

# %% [markdown]
# ## 6. Spalten auswählen

# %% [markdown]
# Wir empfehlen, nur die wirklich notwendigen Spalten in Datwrapper zu kopieren. Deshalb nicht nötige Spalten weglassen:

# %%
df.columns
# Out:
# Index(['Jahr', 'AGS', 'Ort', 'Art', 'Einheit', 'Insgesamt', 'baureifes Land'], dtype='object')

# %%
df = df[['AGS', 'Ort', 'baureifes Land']]

# %%
df.head()
# Out:
#        AGS                                      Ort baureifes Land
# 307  05111             Düsseldorf, Kreisfreie Stadt         959.98
# 311  05112               Duisburg, Kreisfreie Stadt         277.14
# 315  05113                  Essen, Kreisfreie Stadt         322.64
# 319  05114                Krefeld, Kreisfreie Stadt         146.35
# 323  05116        Mönchengladbach, Kreisfreie Stadt         128.48

# %% [markdown]
# ## 7. Daten in die Zwischenablage kopieren

# %% [markdown]
# Statt die Daten als .csv abzuspeichern, kannst du sie auch in die Zwischenablage kopieren (wie mit STRG-C) und in Datawrapper per STRG-V einfügen.

# %%
df.to_clipboard()

# %% [markdown]
# ### 8. Baue deine Karte
# - In Datawrapper wählst du NRW Landkreise als neue Karte aus
# - fügst dann die Daten ein und wählst die entsprechenden Spalten aus (AGS und Wert). AGS steht für 'amtlicher Gemeindeschlüssel'. Datawrapper nutzt diese Gemeindekennziffer, um Daten und Gebiete eindeutig zuzuordnen.
# - Danach kannst du die Karte beschriften und deine Datenquelle angeben und die Karte mit Tooltips, Legende etc. nach deinen Wünschen gestalten.
# - Am Schluss auf 'Veröffentlichen' klicken.

# %% [markdown]
# Prima!
#
# Auf zum nächsten Datenformat:
#
# **[>> Json-Notebook](05_json.ipynb)**
