# %% [markdown]
# ## Real data

# %% [markdown]
# Die Daten im Notebook 03_data.ipynb habe ich für euch vorbereitet.
# Leider begegnen uns Daten in den meisten Fällen nicht so schön maschinenlesbar.
# Die Wahrheit ist: Da draußen ist der Daten-Dschungel und es ist gar nicht so einfach das, was wir brauchen, da rauszuziehen.
#
# **So findest du die bittere Wahrheit heraus**
# - Gehe auf [https://www-genesis.destatis.de/]
# - suche nach 'Durchschnittsalter der habilitierten Personen'.
# - Dann auf 'Werteabruf' und die Tabelle bitte als 'Flat' in ./data abspeichern.

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_rows = 999

# %%
df = pd.read_csv('./data/21351-0002_flat.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-92-9f9267b650ad> in <module>
# ----> 1 df = pd.read_csv('./data/21351-0002_flat.csv')
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 8, saw 3

# %% [markdown]
# ### Huppla - was ist passiert?
#
# Schau dir die Tabelle in einem Tabellenprogramm an.
# Was fällt dir auf?

# %% [markdown]
# - In deutschen Tabellen wird ';' statt ',' als Trenner für .csvs verwendet
# - Dafür schreiben wir in Deutschland '42,3' statt '42.3'
# - In der Tabelle gibt es fehlende Werte, die mit '-'
# - Oft wird auch nicht das weltweit gebräuchliche 'uft-8' als Zeichenformat verwendet, sondern 'latin-1' oder 'iso-8859-1'

# %%
df = pd.read_csv('./data/21351-0002_flat.csv', sep=';', decimal=',', encoding='latin-1')
# sep steht für seperator, also Trennzeichen
# decimal soll '42,3' automatisch in '42.3' umwandeln
# encoding gibt das Zeichenformat an

# %%
df.head(20)
# Out:
#     Statistik_Code               Statistik_Label Zeit_Code Zeit_Label  Zeit  \
# 0            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 1            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 2            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 3            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 4            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 5            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 6            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 7            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 8            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 9            21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 10           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 11           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 12           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 13           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 14           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 15           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 16           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 17           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 18           21351  Statistik der Habilitationen      JAHR       Jahr  2010
# 19           21351  Statistik der Habilitationen      JAHR       Jahr  2010
#
#    1_Merkmal_Code        1_Merkmal_Label 1_Auspraegung_Code  \
# 0           DINSG  Deutschland insgesamt                 DG
# 1           DINSG  Deutschland insgesamt                 DG
# 2           DINSG  Deutschland insgesamt                 DG
# 3           DINSG  Deutschland insgesamt                 DG
# 4           DINSG  Deutschland insgesamt                 DG
# 5           DINSG  Deutschland insgesamt                 DG
# 6           DINSG  Deutschland insgesamt                 DG
# 7           DINSG  Deutschland insgesamt                 DG
# 8           DINSG  Deutschland insgesamt                 DG
# 9           DINSG  Deutschland insgesamt                 DG
# 10          DINSG  Deutschland insgesamt                 DG
# 11          DINSG  Deutschland insgesamt                 DG
# 12          DINSG  Deutschland insgesamt                 DG
# 13          DINSG  Deutschland insgesamt                 DG
# 14          DINSG  Deutschland insgesamt                 DG
# 15          DINSG  Deutschland insgesamt                 DG
# 16          DINSG  Deutschland insgesamt                 DG
# 17          DINSG  Deutschland insgesamt                 DG
# 18          DINSG  Deutschland insgesamt                 DG
# 19          DINSG  Deutschland insgesamt                 DG
#
#    1_Auspraegung_Label 2_Merkmal_Code 2_Merkmal_Label 2_Auspraegung_Code  \
# 0          Deutschland         BILFG1   Fächergruppen         FACHGR-SKW
# 1          Deutschland         BILFG1   Fächergruppen         FACHGR-SKW
# 2          Deutschland         BILFG1   Fächergruppen         FACHGR-SKW
# 3          Deutschland         BILFG1   Fächergruppen         FACHGR-SPR
# 4          Deutschland         BILFG1   Fächergruppen         FACHGR-SPR
# 5          Deutschland         BILFG1   Fächergruppen         FACHGR-SPR
# 6          Deutschland         BILFG1   Fächergruppen        FACHGR-RWSW
# 7          Deutschland         BILFG1   Fächergruppen        FACHGR-RWSW
# 8          Deutschland         BILFG1   Fächergruppen        FACHGR-RWSW
# 9          Deutschland         BILFG1   Fächergruppen        FACHGR-NATW
# 10         Deutschland         BILFG1   Fächergruppen        FACHGR-NATW
# 11         Deutschland         BILFG1   Fächergruppen        FACHGR-NATW
# 12         Deutschland         BILFG1   Fächergruppen      FACHGR-MEDHUM
# 13         Deutschland         BILFG1   Fächergruppen      FACHGR-MEDHUM
# 14         Deutschland         BILFG1   Fächergruppen      FACHGR-MEDHUM
# 15         Deutschland         BILFG1   Fächergruppen      FACHGR-MEDVET
# 16         Deutschland         BILFG1   Fächergruppen      FACHGR-MEDVET
# 17         Deutschland         BILFG1   Fächergruppen      FACHGR-MEDVET
# 18         Deutschland         BILFG1   Fächergruppen        FACHGR-AGRW
# 19         Deutschland         BILFG1   Fächergruppen        FACHGR-AGRW
#
#                                2_Auspraegung_Label 3_Merkmal_Code  \
# 0                            Geisteswissenschaften            GES
# 1                            Geisteswissenschaften            GES
# 2                            Geisteswissenschaften            GES
# 3                                            Sport            GES
# 4                                            Sport            GES
# 5                                            Sport            GES
# 6   Rechts-, Wirtschafts- und Sozialwissenschaften            GES
# 7   Rechts-, Wirtschafts- und Sozialwissenschaften            GES
# 8   Rechts-, Wirtschafts- und Sozialwissenschaften            GES
# 9                  Mathematik, Naturwissenschaften            GES
# 10                 Mathematik, Naturwissenschaften            GES
# 11                 Mathematik, Naturwissenschaften            GES
# 12          Humanmedizin/Gesundheitswissenschaften            GES
# 13          Humanmedizin/Gesundheitswissenschaften            GES
# 14          Humanmedizin/Gesundheitswissenschaften            GES
# 15                                Veterinärmedizin            GES
# 16                                Veterinärmedizin            GES
# 17                                Veterinärmedizin            GES
# 18     Agrar-, Forst- und Ernährungswissenschaften            GES
# 19     Agrar-, Forst- und Ernährungswissenschaften            GES
#
#    3_Merkmal_Label 3_Auspraegung_Code 3_Auspraegung_Label  \
# 0       Geschlecht               GESM            männlich
# 1       Geschlecht               GESW            weiblich
# 2       Geschlecht                NaN           Insgesamt
# 3       Geschlecht               GESM            männlich
# 4       Geschlecht               GESW            weiblich
# 5       Geschlecht                NaN           Insgesamt
# 6       Geschlecht               GESM            männlich
# 7       Geschlecht               GESW            weiblich
# 8       Geschlecht                NaN           Insgesamt
# 9       Geschlecht               GESM            männlich
# 10      Geschlecht               GESW            weiblich
# 11      Geschlecht                NaN           Insgesamt
# 12      Geschlecht               GESM            männlich
# 13      Geschlecht               GESW            weiblich
# 14      Geschlecht                NaN           Insgesamt
# 15      Geschlecht               GESM            männlich
# 16      Geschlecht               GESW            weiblich
# 17      Geschlecht                NaN           Insgesamt
# 18      Geschlecht               GESM            männlich
# 19      Geschlecht               GESW            weiblich
#
#    BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 0                                                42,9
# 1                                                41,6
# 2                                                42,4
# 3                                                41,5
# 4                                                39,3
# 5                                                40,8
# 6                                                39,7
# 7                                                40,8
# 8                                                40,0
# 9                                                40,1
# 10                                               39,1
# 11                                               39,9
# 12                                               40,2
# 13                                               40,9
# 14                                               40,3
# 15                                               42,8
# 16                                               41,4
# 17                                               42,2
# 18                                               43,8
# 19                                               39,9

# %% [markdown]
# ### Puh, das sind viele Spalten!

# %%
# Zeige alle Spalten an 
df.columns
# Out:
# Index(['Statistik_Code', 'Statistik_Label', 'Zeit_Code', 'Zeit_Label', 'Zeit',
#        '1_Merkmal_Code', '1_Merkmal_Label', '1_Auspraegung_Code',
#        '1_Auspraegung_Label', '2_Merkmal_Code', '2_Merkmal_Label',
#        '2_Auspraegung_Code', '2_Auspraegung_Label', '3_Merkmal_Code',
#        '3_Merkmal_Label', '3_Auspraegung_Code', '3_Auspraegung_Label',
#        'BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre'],
#       dtype='object')

# %%
# So wählst du aus, welche Spalten du behalten willst
df = df[['Statistik_Label', 
         'Zeit', 
         '2_Auspraegung_Label',
         '3_Auspraegung_Label',
         'BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre']]

# %%
df.head()
# Out:
#                 Statistik_Label  Zeit    2_Auspraegung_Label  \
# 0  Statistik der Habilitationen  2010  Geisteswissenschaften
# 1  Statistik der Habilitationen  2010  Geisteswissenschaften
# 2  Statistik der Habilitationen  2010  Geisteswissenschaften
# 3  Statistik der Habilitationen  2010                  Sport
# 4  Statistik der Habilitationen  2010                  Sport
#
#   3_Auspraegung_Label  \
# 0            männlich
# 1            weiblich
# 2           Insgesamt
# 3            männlich
# 4            weiblich
#
#   BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 0                                               42,9
# 1                                               41,6
# 2                                               42,4
# 3                                               41,5
# 4                                               39,3

# %%
# So kannst du ausgewählte Spalten weglassen 
df.drop(['Statistik_Label'], axis='columns', inplace=True)

# %%
# So sieht die Tabelle schon übersichtlicher aus
df.sample(5)
# Out:
#      Zeit    2_Auspraegung_Label 3_Auspraegung_Label  \
# 136  2014                  Sport            weiblich
# 83   2012       Veterinärmedizin           Insgesamt
# 299  2019  Geisteswissenschaften           Insgesamt
# 37   2011                  Sport            weiblich
# 234  2017                  Sport            männlich
#
#     BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 136                                               38,1
# 83                                                41,1
# 299                                               43,7
# 37                                                   .
# 234                                               41,3

# %% [markdown]
# ## Daten filtern

# %% [markdown]
# Wir müssen auswählen, was wir als in der Grafik darstellen wollen. Sagen wir mal uns interessiert besonders, wie sich das Alter bei der Habilitation im Bereich Kunst- und Kunstgeschichte Insgesamt verändert hat:

# %%
# So wählst du den DataFrame aus, wo die Spalte "2_Ausprägung_Label" den Wert 'Kunst, Kunstgeschichte' enthält 
df[(df["2_Auspraegung_Label"] == 'Kunst, Kunstwissenschaft')]
# Out:
#      Zeit       2_Auspraegung_Label 3_Auspraegung_Label  \
# 27   2010  Kunst, Kunstwissenschaft            männlich
# 28   2010  Kunst, Kunstwissenschaft            weiblich
# 29   2010  Kunst, Kunstwissenschaft           Insgesamt
# 60   2011  Kunst, Kunstwissenschaft            männlich
# 61   2011  Kunst, Kunstwissenschaft            weiblich
# 62   2011  Kunst, Kunstwissenschaft           Insgesamt
# 93   2012  Kunst, Kunstwissenschaft            männlich
# 94   2012  Kunst, Kunstwissenschaft            weiblich
# 95   2012  Kunst, Kunstwissenschaft           Insgesamt
# 126  2013  Kunst, Kunstwissenschaft            männlich
# 127  2013  Kunst, Kunstwissenschaft            weiblich
# 128  2013  Kunst, Kunstwissenschaft           Insgesamt
# 159  2014  Kunst, Kunstwissenschaft            männlich
# 160  2014  Kunst, Kunstwissenschaft            weiblich
# 161  2014  Kunst, Kunstwissenschaft           Insgesamt
# 192  2015  Kunst, Kunstwissenschaft            männlich
# 193  2015  Kunst, Kunstwissenschaft            weiblich
# 194  2015  Kunst, Kunstwissenschaft           Insgesamt
# 225  2016  Kunst, Kunstwissenschaft            männlich
# 226  2016  Kunst, Kunstwissenschaft            weiblich
# 227  2016  Kunst, Kunstwissenschaft           Insgesamt
# 258  2017  Kunst, Kunstwissenschaft            männlich
# 259  2017  Kunst, Kunstwissenschaft            weiblich
# 260  2017  Kunst, Kunstwissenschaft           Insgesamt
# 291  2018  Kunst, Kunstwissenschaft            männlich
# 292  2018  Kunst, Kunstwissenschaft            weiblich
# 293  2018  Kunst, Kunstwissenschaft           Insgesamt
# 324  2019  Kunst, Kunstwissenschaft            männlich
# 325  2019  Kunst, Kunstwissenschaft            weiblich
# 326  2019  Kunst, Kunstwissenschaft           Insgesamt
#
#     BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 27                                                45,0
# 28                                                47,6
# 29                                                46,1
# 60                                                45,3
# 61                                                45,4
# 62                                                45,4
# 93                                                41,9
# 94                                                47,1
# 95                                                45,1
# 126                                               41,5
# 127                                               46,9
# 128                                               45,1
# 159                                               43,4
# 160                                               43,0
# 161                                               43,3
# 192                                               44,3
# 193                                               44,5
# 194                                               44,4
# 225                                               43,1
# 226                                               45,0
# 227                                               44,6
# 258                                               45,6
# 259                                               44,6
# 260                                               45,2
# 291                                               43,5
# 292                                               45,6
# 293                                               44,5
# 324                                               50,1
# 325                                               45,4
# 326                                               48,1

# %%
# Wenn du nur die Daten für 'Insgesamt' auswählen willst
df[(df["2_Auspraegung_Label"] == 'Kunst, Kunstwissenschaft') & (df["3_Auspraegung_Label"] == 'Insgesamt')]
# Out:
#      Zeit       2_Auspraegung_Label 3_Auspraegung_Label  \
# 29   2010  Kunst, Kunstwissenschaft           Insgesamt
# 62   2011  Kunst, Kunstwissenschaft           Insgesamt
# 95   2012  Kunst, Kunstwissenschaft           Insgesamt
# 128  2013  Kunst, Kunstwissenschaft           Insgesamt
# 161  2014  Kunst, Kunstwissenschaft           Insgesamt
# 194  2015  Kunst, Kunstwissenschaft           Insgesamt
# 227  2016  Kunst, Kunstwissenschaft           Insgesamt
# 260  2017  Kunst, Kunstwissenschaft           Insgesamt
# 293  2018  Kunst, Kunstwissenschaft           Insgesamt
# 326  2019  Kunst, Kunstwissenschaft           Insgesamt
#
#     BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 29                                                46,1
# 62                                                45,4
# 95                                                45,1
# 128                                               45,1
# 161                                               43,3
# 194                                               44,4
# 227                                               44,6
# 260                                               45,2
# 293                                               44,5
# 326                                               48,1

# %%
# Wenn du für Kunstgeschichte die Daten für 'männlich' oder 'weiblich' auswählen willst
df[(df["2_Auspraegung_Label"] == 'Kunst, Kunstwissenschaft') & ((df["3_Auspraegung_Label"] == 'weiblich') | (df["3_Auspraegung_Label"] =='männlich')) ]
# Out:
#      Zeit       2_Auspraegung_Label 3_Auspraegung_Label  \
# 27   2010  Kunst, Kunstwissenschaft            männlich
# 28   2010  Kunst, Kunstwissenschaft            weiblich
# 60   2011  Kunst, Kunstwissenschaft            männlich
# 61   2011  Kunst, Kunstwissenschaft            weiblich
# 93   2012  Kunst, Kunstwissenschaft            männlich
# 94   2012  Kunst, Kunstwissenschaft            weiblich
# 126  2013  Kunst, Kunstwissenschaft            männlich
# 127  2013  Kunst, Kunstwissenschaft            weiblich
# 159  2014  Kunst, Kunstwissenschaft            männlich
# 160  2014  Kunst, Kunstwissenschaft            weiblich
# 192  2015  Kunst, Kunstwissenschaft            männlich
# 193  2015  Kunst, Kunstwissenschaft            weiblich
# 225  2016  Kunst, Kunstwissenschaft            männlich
# 226  2016  Kunst, Kunstwissenschaft            weiblich
# 258  2017  Kunst, Kunstwissenschaft            männlich
# 259  2017  Kunst, Kunstwissenschaft            weiblich
# 291  2018  Kunst, Kunstwissenschaft            männlich
# 292  2018  Kunst, Kunstwissenschaft            weiblich
# 324  2019  Kunst, Kunstwissenschaft            männlich
# 325  2019  Kunst, Kunstwissenschaft            weiblich
#
#     BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 27                                                45,0
# 28                                                47,6
# 60                                                45,3
# 61                                                45,4
# 93                                                41,9
# 94                                                47,1
# 126                                               41,5
# 127                                               46,9
# 159                                               43,4
# 160                                               43,0
# 192                                               44,3
# 193                                               44,5
# 225                                               43,1
# 226                                               45,0
# 258                                               45,6
# 259                                               44,6
# 291                                               43,5
# 292                                               45,6
# 324                                               50,1
# 325                                               45,4

# %%
# Wenn du dir sicher bist, dass das richtige gefiltert wird,kannst du einen neuen DataFrame erzeugen. So bleiben die Ursprungsdaten erhalten.
kunst = df[(df["2_Auspraegung_Label"] == 'Kunst, Kunstwissenschaft') & ((df["3_Auspraegung_Label"] == 'weiblich') | (df["3_Auspraegung_Label"] =='männlich')) ]

# %%
kunst
# Out:
#      Zeit       2_Auspraegung_Label 3_Auspraegung_Label  \
# 27   2010  Kunst, Kunstwissenschaft            männlich
# 28   2010  Kunst, Kunstwissenschaft            weiblich
# 60   2011  Kunst, Kunstwissenschaft            männlich
# 61   2011  Kunst, Kunstwissenschaft            weiblich
# 93   2012  Kunst, Kunstwissenschaft            männlich
# 94   2012  Kunst, Kunstwissenschaft            weiblich
# 126  2013  Kunst, Kunstwissenschaft            männlich
# 127  2013  Kunst, Kunstwissenschaft            weiblich
# 159  2014  Kunst, Kunstwissenschaft            männlich
# 160  2014  Kunst, Kunstwissenschaft            weiblich
# 192  2015  Kunst, Kunstwissenschaft            männlich
# 193  2015  Kunst, Kunstwissenschaft            weiblich
# 225  2016  Kunst, Kunstwissenschaft            männlich
# 226  2016  Kunst, Kunstwissenschaft            weiblich
# 258  2017  Kunst, Kunstwissenschaft            männlich
# 259  2017  Kunst, Kunstwissenschaft            weiblich
# 291  2018  Kunst, Kunstwissenschaft            männlich
# 292  2018  Kunst, Kunstwissenschaft            weiblich
# 324  2019  Kunst, Kunstwissenschaft            männlich
# 325  2019  Kunst, Kunstwissenschaft            weiblich
#
#     BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 27                                                45,0
# 28                                                47,6
# 60                                                45,3
# 61                                                45,4
# 93                                                41,9
# 94                                                47,1
# 126                                               41,5
# 127                                               46,9
# 159                                               43,4
# 160                                               43,0
# 192                                               44,3
# 193                                               44,5
# 225                                               43,1
# 226                                               45,0
# 258                                               45,6
# 259                                               44,6
# 291                                               43,5
# 292                                               45,6
# 324                                               50,1
# 325                                               45,4

# %% [markdown]
# ## Visualisierung

# %%
kunst
# Out:
#      Zeit       2_Auspraegung_Label 3_Auspraegung_Label  \
# 27   2010  Kunst, Kunstwissenschaft            männlich
# 28   2010  Kunst, Kunstwissenschaft            weiblich
# 60   2011  Kunst, Kunstwissenschaft            männlich
# 61   2011  Kunst, Kunstwissenschaft            weiblich
# 93   2012  Kunst, Kunstwissenschaft            männlich
# 94   2012  Kunst, Kunstwissenschaft            weiblich
# 126  2013  Kunst, Kunstwissenschaft            männlich
# 127  2013  Kunst, Kunstwissenschaft            weiblich
# 159  2014  Kunst, Kunstwissenschaft            männlich
# 160  2014  Kunst, Kunstwissenschaft            weiblich
# 192  2015  Kunst, Kunstwissenschaft            männlich
# 193  2015  Kunst, Kunstwissenschaft            weiblich
# 225  2016  Kunst, Kunstwissenschaft            männlich
# 226  2016  Kunst, Kunstwissenschaft            weiblich
# 258  2017  Kunst, Kunstwissenschaft            männlich
# 259  2017  Kunst, Kunstwissenschaft            weiblich
# 291  2018  Kunst, Kunstwissenschaft            männlich
# 292  2018  Kunst, Kunstwissenschaft            weiblich
# 324  2019  Kunst, Kunstwissenschaft            männlich
# 325  2019  Kunst, Kunstwissenschaft            weiblich
#
#     BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 27                                                45,0
# 28                                                47,6
# 60                                                45,3
# 61                                                45,4
# 93                                                41,9
# 94                                                47,1
# 126                                               41,5
# 127                                               46,9
# 159                                               43,4
# 160                                               43,0
# 192                                               44,3
# 193                                               44,5
# 225                                               43,1
# 226                                               45,0
# 258                                               45,6
# 259                                               44,6
# 291                                               43,5
# 292                                               45,6
# 324                                               50,1
# 325                                               45,4

# %%
kunst = kunst.pivot(index='Zeit', columns='3_Auspraegung_Label', values='BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre')

# %%
kunst
# Out:
# 3_Auspraegung_Label männlich weiblich
# Zeit
# 2010                    45,0     47,6
# 2011                    45,3     45,4
# 2012                    41,9     47,1
# 2013                    41,5     46,9
# 2014                    43,4     43,0
# 2015                    44,3     44,5
# 2016                    43,1     45,0
# 2017                    45,6     44,6
# 2018                    43,5     45,6
# 2019                    50,1     45,4

# %%
kunst.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-3357fc87840e> in <module>
# ----> 1 kunst.plot()
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %% [markdown]
# ### Hm, das mit dem Zahlenformat hat nicht geklappt

# %%
# In der Spalte mit dem Durchschnittsalter ist das Komma leider nicht korrekt ersetzt worden. Shit happens.
# Eine einzelne Spalte kann mit df.Name_der_Spalte aufgerufen werden. (Falls der Name der Spalte Leerzeichen oder Sonderzeichen enthält mit df['Name der Spalte'])
kunst.männlich
# Out:
# Zeit
# 2010    45,0
# 2011    45,3
# 2012    41,9
# 2013    41,5
# 2014    43,4
# 2015    44,3
# 2016    43,1
# 2017    45,6
# 2018    43,5
# 2019    50,1
# Name: männlich, dtype: object

# %%
# Dass das nicht geklappt hat, liegt daran, dass es ürsprünglich mal fehlende Werte gab, die das Zeichen '-' enthalten haben (Bei 'Veterinärmedizin' gibt es in der .csv von destatis keine Daten ab 2015)
# Durch das Filtern sind wir diese seltsamen Werte losgeworden. Leider enthalten unsere Werte immer noch ',' statt '.'.
# Um zu sehen, welche Werte vorhanden sind, kannst du zum Beispiel zählen lassen, wie welche Werte wie oft vorkommen.   
kunst.weiblich.value_counts()
# Out:
# 45,4    2
# 47,6    1
# 46,9    1
# 45,6    1
# 47,1    1
# 45,0    1
# 44,6    1
# 44,5    1
# 43,0    1
# Name: weiblich, dtype: int64

# %%
# Also bereinigen wir die Spalte selbst. Pandas ist gut darin, Strings zu verändern. In diesem Fall wollen wir in unserer Spalte ',' durch '.' ersetzen
kunst.männlich = kunst.männlich.str.replace(',', '.')
kunst.weiblich = kunst.weiblich.str.replace(',', '.')

# %%
kunst.head()
# Out:
# 3_Auspraegung_Label männlich weiblich
# Zeit
# 2010                    45.0     47.6
# 2011                    45.3     45.4
# 2012                    41.9     47.1
# 2013                    41.5     46.9
# 2014                    43.4     43.0

# %%
# Die ',' wurden zwar durch '.' ersetzt, aber der Datentyp ist immer noch 'Object'. Wir brauchen aber numerische Daten (int, float) zum plotten. 
kunst.dtypes
# Out:
# 3_Auspraegung_Label
# männlich    object
# weiblich    object
# dtype: object

# %%
kunst.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-3357fc87840e> in <module>
# ----> 1 kunst.plot()
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# ~/pfv/myvenv/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
# So änderst du den Datentyp auf float
kunst.männlich = kunst.männlich.astype('float')
kunst.weiblich = kunst.weiblich.astype('float')

# %%
kunst
# Out:
# 3_Auspraegung_Label  männlich  weiblich
# Zeit
# 2010                     45.0      47.6
# 2011                     45.3      45.4
# 2012                     41.9      47.1
# 2013                     41.5      46.9
# 2014                     43.4      43.0
# 2015                     44.3      44.5
# 2016                     43.1      45.0
# 2017                     45.6      44.6
# 2018                     43.5      45.6
# 2019                     50.1      45.4

# %%
kunst.plot()
# Out:
# <AxesSubplot:xlabel='Zeit'>

# %%
kunst.plot(kind="bar", figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Zeit'>

# %% [markdown]
# ## Übung

# %%
# Zeige, wie sich das Durchschnittsalter der habilitierten Personen in Deutschland insgesamt verändert hat

insgesamt = df[(df["2_Auspraegung_Label"] == 'Insgesamt') & (df["3_Auspraegung_Label"] == 'Insgesamt')]

# %%
insgesamt = insgesamt.set_index('Zeit')

# %%
insgesamt.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre = insgesamt.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre.str.replace(',', '.')

# %%
insgesamt.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre = insgesamt.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre.astype('float')

# %%
# Stelle die Veränderung in einem Linechart dar

insgesamt.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Zeit'>

# %% [markdown]
# ## Gruppieren

# %% [markdown]
# ### In welchem Bereich ist das Habilitationsalter am höchsten?

# %% [markdown]
# Um Durchschnitte berechnen zu können, muss die Werte Spalte den Datentyp 'float' haben, also ausschließlich Nummern enthalten.

# %%
df.dtypes
# Out:
# Zeit                                                             int64
# 2_Auspraegung_Label                                             object
# 3_Auspraegung_Label                                             object
# BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre    object
# dtype: object

# %% [markdown]
# Um die Spalte zu bereinigen:
#
# - müssen wir den kompletten Datensatz von fehlendenden Werten befreien
# - müssen wir die Spalte in numerische Werte umwandeln

# %%
# Durch value_counts sehen wir, dass häufig '-' bei fehlenden Daten auftaucht.
df['BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre'].value_counts().head()
# Out:
# -       45
# 40,8    17
# 41,0    12
# 41,1    11
# 40,9    11
# Name: BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre, dtype: int64

# %%
# Anzeigen, in welchen Fällen das so ist:
df[df.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre == '-']
# Out:
#      Zeit                                2_Auspraegung_Label  \
# 21   2010  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 22   2010  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 23   2010  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 54   2011  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 55   2011  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 56   2011  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 87   2012  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 88   2012  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 89   2012  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 120  2013  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 121  2013  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 122  2013  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 153  2014  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 154  2014  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 155  2014  Agrar-, Forst- u.Ernährungswiss., Veterinärmed...
# 180  2015                                   Veterinärmedizin
# 181  2015                                   Veterinärmedizin
# 182  2015                                   Veterinärmedizin
# 183  2015        Agrar-, Forst- und Ernährungswissenschaften
# 184  2015        Agrar-, Forst- und Ernährungswissenschaften
# 185  2015        Agrar-, Forst- und Ernährungswissenschaften
# 213  2016                                   Veterinärmedizin
# 214  2016                                   Veterinärmedizin
# 215  2016                                   Veterinärmedizin
# 216  2016        Agrar-, Forst- und Ernährungswissenschaften
# 217  2016        Agrar-, Forst- und Ernährungswissenschaften
# 218  2016        Agrar-, Forst- und Ernährungswissenschaften
# 246  2017                                   Veterinärmedizin
# 247  2017                                   Veterinärmedizin
# 248  2017                                   Veterinärmedizin
# 249  2017        Agrar-, Forst- und Ernährungswissenschaften
# 250  2017        Agrar-, Forst- und Ernährungswissenschaften
# 251  2017        Agrar-, Forst- und Ernährungswissenschaften
# 279  2018                                   Veterinärmedizin
# 280  2018                                   Veterinärmedizin
# 281  2018                                   Veterinärmedizin
# 282  2018        Agrar-, Forst- und Ernährungswissenschaften
# 283  2018        Agrar-, Forst- und Ernährungswissenschaften
# 284  2018        Agrar-, Forst- und Ernährungswissenschaften
# 312  2019                                   Veterinärmedizin
# 313  2019                                   Veterinärmedizin
# 314  2019                                   Veterinärmedizin
# 315  2019        Agrar-, Forst- und Ernährungswissenschaften
# 316  2019        Agrar-, Forst- und Ernährungswissenschaften
# 317  2019        Agrar-, Forst- und Ernährungswissenschaften
#
#     3_Auspraegung_Label  \
# 21             männlich
# 22             weiblich
# 23            Insgesamt
# 54             männlich
# 55             weiblich
# 56            Insgesamt
# 87             männlich
# 88             weiblich
# 89            Insgesamt
# 120            männlich
# 121            weiblich
# 122           Insgesamt
# 153            männlich
# 154            weiblich
# 155           Insgesamt
# 180            männlich
# 181            weiblich
# 182           Insgesamt
# 183            männlich
# 184            weiblich
# 185           Insgesamt
# 213            männlich
# 214            weiblich
# 215           Insgesamt
# 216            männlich
# 217            weiblich
# 218           Insgesamt
# 246            männlich
# 247            weiblich
# 248           Insgesamt
# 249            männlich
# 250            weiblich
# 251           Insgesamt
# 279            männlich
# 280            weiblich
# 281           Insgesamt
# 282            männlich
# 283            weiblich
# 284           Insgesamt
# 312            männlich
# 313            weiblich
# 314           Insgesamt
# 315            männlich
# 316            weiblich
# 317           Insgesamt
#
#     BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 21                                                   -
# 22                                                   -
# 23                                                   -
# 54                                                   -
# 55                                                   -
# 56                                                   -
# 87                                                   -
# 88                                                   -
# 89                                                   -
# 120                                                  -
# 121                                                  -
# 122                                                  -
# 153                                                  -
# 154                                                  -
# 155                                                  -
# 180                                                  -
# 181                                                  -
# 182                                                  -
# 183                                                  -
# 184                                                  -
# 185                                                  -
# 213                                                  -
# 214                                                  -
# 215                                                  -
# 216                                                  -
# 217                                                  -
# 218                                                  -
# 246                                                  -
# 247                                                  -
# 248                                                  -
# 249                                                  -
# 250                                                  -
# 251                                                  -
# 279                                                  -
# 280                                                  -
# 281                                                  -
# 282                                                  -
# 283                                                  -
# 284                                                  -
# 312                                                  -
# 313                                                  -
# 314                                                  -
# 315                                                  -
# 316                                                  -
# 317                                                  -

# %%
# Die entsprechenden Fachrichtungen aussortieren
df = df[(df['2_Auspraegung_Label'] != 'Veterinärmedizin') & 
        (df['2_Auspraegung_Label'] != 'Agrar-, Forst- und Ernährungswissenschaften') & 
        (df['2_Auspraegung_Label'] != 'Agrar-, Forst- u.Ernährungswiss., Veterinärmedizin') &
        (df['2_Auspraegung_Label'] != 'Sport')
       ]

# %%
# ',' Werte durch '.' ersetzen
df.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre = df.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre.str.replace(',', '.')

# %%
# Datentyp auf float ändern
df.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre = df.BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre.astype('float')

# %%
# So wird der Durchschnitt der Jahre gebildet
alter_im_schnitt = df.groupby('2_Auspraegung_Label').mean().round(2).sort_values('BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre', ascending=False)
alter_im_schnitt
# Out:
#                                                   Zeit  \
# 2_Auspraegung_Label
# Kunst, Kunstwissenschaft                        2014.5
# Geisteswissenschaften                           2014.5
# Ingenieurwissenschaften                         2014.5
# Insgesamt                                       2014.5
# Mathematik, Naturwissenschaften                 2014.5
# Humanmedizin/Gesundheitswissenschaften          2014.5
# Rechts-, Wirtschafts- und Sozialwissenschaften  2014.5
#
#                                                 BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre
# 2_Auspraegung_Label
# Kunst, Kunstwissenschaft                                                                    45.02
# Geisteswissenschaften                                                                       42.98
# Ingenieurwissenschaften                                                                     42.56
# Insgesamt                                                                                   41.23
# Mathematik, Naturwissenschaften                                                             40.95
# Humanmedizin/Gesundheitswissenschaften                                                      40.70
# Rechts-, Wirtschafts- und Sozialwissenschaften                                              40.33

# %% [markdown]
# Hier noch mal Schritt für Schitt erklärt:
#
# Um das Alter im Schnitt zu berechnen
# - gruppieren wir nach '2_Ausprägung_Label': .groupby('2_Auspraegung_Label')
# - nehmen jeweils den Durchschnitt: .mean()
# - runden das Ergebnis auf 2 Stellen: .round(2)
# - sortieren die Werte absteigend: .sort_values('BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre', ascending=False)

# %%
# Daten plotten
alter_im_schnitt.plot.barh(y='BIL051__Durchschnittsalter_der_habilitierten_Personen__Jahre', 
                                           legend=False, 
                                           title="Durchschnittsalter der habilitierten Personen",
                                          figsize=(12,10))
# Out:
# <AxesSubplot:title={'center':'Durchschnittsalter der habilitierten Personen'}, ylabel='2_Auspraegung_Label'>

# %% [markdown]
# ## Übung
#
# Aus welchem Gebiet stammen im Schnitt die jüngsten männlichen Eingebürgerten?

# %% [markdown]
# - Suche auf [https://www-genesis.destatis.de/] nach 'Durchschnittsalter der Eingebürgerten: Deutschland, Jahre, Ländergruppierungen/Staatsangehörigkeit, Geschlecht,Familienstand
# - Lade den Datensatz als Flat.csv herunter
# - Lesen ihn als DataFrame ein
# - Wähle folgende Spalten aus: '2_Auspraegung_Label', '3_Auspraegung_Label', '4_Auspraegung_Label', 'BEV064__Durchschnittsalter_der_Eingebuergerten__Jahre'
# - Filtere auf 'männlich' und 'ledig
# - Sortiere den Datensatz nach dem Durchschnittsalter

# %%
df = pd.read_csv('./data/12511-0007_flat.csv', sep=';', decimal=',', encoding='latin-1')

# %%
df.columns
# Out:
# Index(['Statistik_Code', 'Statistik_Label', 'Zeit_Code', 'Zeit_Label', 'Zeit',
#        '1_Merkmal_Code', '1_Merkmal_Label', '1_Auspraegung_Code',
#        '1_Auspraegung_Label', '2_Merkmal_Code', '2_Merkmal_Label',
#        '2_Auspraegung_Code', '2_Auspraegung_Label', '3_Merkmal_Code',
#        '3_Merkmal_Label', '3_Auspraegung_Code', '3_Auspraegung_Label',
#        '4_Merkmal_Code', '4_Merkmal_Label', '4_Auspraegung_Code',
#        '4_Auspraegung_Label',
#        'BEV064__Durchschnittsalter_der_Eingebuergerten__Jahre'],
#       dtype='object')

# %%
df = df[['2_Auspraegung_Label', '3_Auspraegung_Label', '4_Auspraegung_Label', 'BEV064__Durchschnittsalter_der_Eingebuergerten__Jahre']]

# %%
df.head()
# Out:
#   2_Auspraegung_Label 3_Auspraegung_Label  \
# 0            männlich               ledig
# 1            männlich               ledig
# 2            männlich               ledig
# 3            männlich               ledig
# 4            männlich               ledig
#
#                        4_Auspraegung_Label  \
# 0                                Insgesamt
# 1                                   Europa
# 2                  EU-28 (seit 01.07.2013)
# 3  Drittstaaten zu EU-28 (seit 01.07.2013)
# 4                   EU-27 (bis 30.06.2013)
#
#   BEV064__Durchschnittsalter_der_Eingebuergerten__Jahre
# 0                                                 24
# 1                                                 25
# 2                                                 27
# 3                                                 22
# 4                                                 28

# %%
df['2_Auspraegung_Label'].value_counts()
# Out:
# männlich    273
# weiblich    273
# Name: 2_Auspraegung_Label, dtype: int64

# %%
df = df[(df['2_Auspraegung_Label'] == 'männlich') & 
        (df['3_Auspraegung_Label'] == 'ledig')]

# %%
df.sort_values('BEV064__Durchschnittsalter_der_Eingebuergerten__Jahre', ascending=True).head()
# Out:
#    2_Auspraegung_Label 3_Auspraegung_Label  \
# 30            männlich               ledig
# 36            männlich               ledig
# 35            männlich               ledig
# 22            männlich               ledig
# 37            männlich               ledig
#
#                              4_Auspraegung_Label  \
# 30                          Süd- und Südostasien
# 36             Gebiet der ehemaligen Sowjetunion
# 35  Gebiet des ehemaligen Serbien und Montenegro
# 22                                     Ostafrika
# 37        Gebiet der ehemaligen Tschechoslowakei
#
#    BEV064__Durchschnittsalter_der_Eingebuergerten__Jahre
# 30                                                 20
# 36                                                 21
# 35                                                 21
# 22                                                 21
# 37                                                 21

# %% [markdown]
# ## Übung

# %% [markdown]
# - Such dir einen Datensatz in [https://www-genesis.destatis.de/]
# - Lade den Datensatz als Flat-Table herunter
# - Lese ihn als DataFrame ein
# - Stelle dir eine Frage zu diesem Datensatz, die du beantworten willst
# - Wähle die Spalten aus, die du brauchst
# - Filtere den Datensatz ggf. so, dass fehlende Daten ausgeblendet werden
# - Gruppiere oder sortiere falls nötig
# - Beantworte deine Frage

# %% [markdown]
# Hervorragend!
#
# Weiter geht es mit dem
#
# **[>> Datenportal Notebook](04b_real_real_data_datenportal_csv.ipynb)**
