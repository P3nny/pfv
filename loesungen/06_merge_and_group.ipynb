# %% [markdown]
# # Datensätze miteinander verbinden

# %%
import pandas as pd

# %% [markdown]
# Schauen wir uns einen Ausschnitt aus einer Umfrage bei allen Schulleiter*innen in NRW an, die gerade im WDR durchgeführt wird.

# %%
df = pd.read_csv('./data/umfrage_schulleiter.csv')

# %%
df
# Out:
#            Ort             schulform anzahl_schueler  F1_ausstattung
# 0       Aachen          Privatschule             178             3.0
# 1       Aachen             Gymnasium             NaN             4.0
# 2       Aachen             Gymnasium            1250             3.0
# 3       Aachen            Realschule             640             5.0
# 4       Aachen           Grundschule             195             4.0
# ..         ...                   ...             ...             ...
# 768  Wuppertal          Förderschule             203             4.0
# 769   Würselen           Grundschule             209             5.0
# 770   Würselen  Weiterbildungskolleg             310             4.0
# 771     Xanten          Berufskolleg             365             2.0
# 772    Zülpich           Grundschule             128             5.0
#
# [773 rows x 4 columns]

# %% [markdown]
# ## Wo vergeben Schulleiter*innen in NRW die besten Noten für die technische Ausstattung an ihrer Schule?
# Unter f1_ausstattung haben die Schulleiter*innen Schulnoten für die Ausstattung ihrer Schule vergeben.
# Im Datensatz gibt es nur die Spalte 'Ort', die einen Gemeindenamen enthält.
# Um die Daten nach Region analysieren und auch später visualisieren zu können, wäre es hilfreich, weitere Angaben wie den AGS, Regierungsbezirk etc. zu haben.

# %% [markdown]
# ### Allgemeine NRW-Daten einladen

# %%
# Laden der generellen Daten zu den NRW-Gemeinden 
city_data = pd.read_json('./data/nrw_data.json', orient='columns', dtype={'keyCity': 'str'})

# %%
city_data.sample()
# Out:
#             city   type  keyCity                state studioRadio  studio  \
# 213  Lüdenscheid  Stadt  5962032  Nordrhein-Westfalen      Siegen  Siegen
#
#         region          district
# 213  Westfalen  Märkischer Kreis

# %% [markdown]
# KeyCity enthält in diesem Fall den AGS ohne führende Null.

# %% [markdown]
# Wir wollen aus dem AGS die Regierungsbezirke-Namen ablesen, dafür erzeigen wir eine neue Spalte 'regierungsbezirk', die die erste Stelle aus dem AGS enthält.

# %%
city_data['regierungsbezirk'] = city_data.keyCity.str[1:2]

# %%
city_data.sample()
# Out:
#         city      type  keyCity                state studioRadio studio  \
# 387  Windeck  Gemeinde  5382076  Nordrhein-Westfalen        Köln   Bonn
#
#         region          district regierungsbezirk
# 387  Rheinland  Rhein-Sieg-Kreis                3

# %%
city_data['regierungsbezirk'] = city_data.regierungsbezirk.str.replace('1', 'Düsseldorf')
city_data['regierungsbezirk'] = city_data.regierungsbezirk.str.replace('3', 'Köln')
city_data['regierungsbezirk'] = city_data.regierungsbezirk.str.replace('5', 'Münster')
city_data['regierungsbezirk'] = city_data.regierungsbezirk.str.replace('7', 'Detmold')
city_data['regierungsbezirk'] = city_data.regierungsbezirk.str.replace('9', 'Arnsberg')

# %%
city_data.regierungsbezirk.value_counts()
# Out:
# Köln          99
# Arnsberg      83
# Münster       78
# Detmold       70
# Düsseldorf    66
# Name: regierungsbezirk, dtype: int64

# %% [markdown]
# ### Datensätze verbinden

# %%
# Um die Datensätze zu verbinden, setzen wir in beiden Fällen den Index auf die Ort-Spalte
df = df.set_index('Ort')

# %%
df.sample()
# Out:
#           schulform anzahl_schueler  F1_ausstattung
# Ort
# Lemgo  Berufskolleg            1200             2.0

# %%
city_data = city_data.set_index('city')

# %%
city_data.sample()
# Out:
#         type  keyCity                state studioRadio    studio     region  \
# city
# Moers  Stadt  5170024  Nordrhein-Westfalen    Duisburg  Duisburg  Rheinland
#
#       district regierungsbezirk
# city
# Moers    Wesel       Düsseldorf

# %%
# Um zu kontrollieren, dass keine Spalten verloren gehen, überprüfen wir die Länge der beiden Datensätze
len(df), len(city_data)
# Out:
# (773, 396)

# %%
# Join verbindet beide Datensätze anhand des index
df = df.join(city_data)

# %%
len(df)
# Out:
# 773

# %%
df.sample(10)
# Out:
#                      schulform anzahl_schueler  F1_ausstattung   type  \
# Düren              Grundschule             300             5.0  Stadt
# Aachen             Grundschule             130             4.0  Stadt
# Velbert           Förderschule             136             2.0  Stadt
# Ahaus             Gesamtschule            1214             NaN  Stadt
# Elsdorf           Förderschule             140             5.0  Stadt
# Wermelskirchen     Grundschule             175             2.0  Stadt
# Bonn               Grundschule             278             4.0  Stadt
# Viersen           Gesamtschule            1265             4.0  Stadt
# Neuenrade       Sekundarschule             400             5.0  Stadt
# Neuss              Grundschule             302             4.0  Stadt
#
#                 keyCity                state studioRadio      studio  \
# Düren           5358008  Nordrhein-Westfalen      Aachen      Aachen
# Aachen          5334002  Nordrhein-Westfalen      Aachen      Aachen
# Velbert         5158032  Nordrhein-Westfalen   Wuppertal   Wuppertal
# Ahaus           5554004  Nordrhein-Westfalen     Münster     Münster
# Elsdorf         5362016  Nordrhein-Westfalen        Köln        Köln
# Wermelskirchen  5378032  Nordrhein-Westfalen   Wuppertal   Wuppertal
# Bonn            5314000  Nordrhein-Westfalen        Köln        Bonn
# Viersen         5166032  Nordrhein-Westfalen  Düsseldorf  Düsseldorf
# Neuenrade       5962048  Nordrhein-Westfalen      Siegen      Siegen
# Neuss           5162024  Nordrhein-Westfalen  Düsseldorf  Düsseldorf
#
#                    region                    district regierungsbezirk
# Düren           Rheinland                       Düren             Köln
# Aachen          Rheinland         Städteregion Aachen             Köln
# Velbert         Rheinland                    Mettmann       Düsseldorf
# Ahaus           Westfalen                      Borken          Münster
# Elsdorf         Rheinland            Rhein-Erft-Kreis             Köln
# Wermelskirchen  Rheinland  Rheinisch-Bergischer Kreis             Köln
# Bonn            Rheinland                        Bonn             Köln
# Viersen         Rheinland                     Viersen       Düsseldorf
# Neuenrade       Westfalen            Märkischer Kreis         Arnsberg
# Neuss           Rheinland           Rhein-Kreis Neuss       Düsseldorf

# %% [markdown]
# #### Tipp:
#
# Es gibt noch weitere Arten, Datensätze miteinander zu verknüpfen, einen ersten Überblick findest du hier:
#         [Chris Albon: Join And Merge Pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_join_merge_dataframe/)

# %% [markdown]
# ### Wie bewerten Sie die digitale Ausstattung Ihrer Schule zurzeit?

# %%
# Gibt es Schulen, die diese Frage nicht beantwortet haben
df.F1_ausstattung.value_counts(dropna=False)
# Out:
# 3.0    185
# 5.0    177
# 2.0    159
# 4.0    152
# 6.0     58
# 1.0     32
# NaN     10
# Name: F1_ausstattung, dtype: int64

# %%
df[df.F1_ausstattung.isna()]
# Out:
#                   schulform anzahl_schueler  F1_ausstattung      type  \
# Ahaus          Gesamtschule            1214             NaN     Stadt
# Bielefeld       Grundschule             NaN             NaN     Stadt
# Bocholt        Berufskolleg             378             NaN     Stadt
# Düsseldorf              NaN             NaN             NaN     Stadt
# Gelsenkirchen           NaN             NaN             NaN     Stadt
# Herne           Grundschule             NaN             NaN     Stadt
# Köln           Förderschule             164             NaN     Stadt
# Mettmann        Grundschule             260             NaN     Stadt
# Windeck           Gymnasium             650             NaN  Gemeinde
# Windeck         Grundschule             103             NaN  Gemeinde
#
#                keyCity                state studioRadio      studio  \
# Ahaus          5554004  Nordrhein-Westfalen     Münster     Münster
# Bielefeld      5711000  Nordrhein-Westfalen   Bielefeld   Bielefeld
# Bocholt        5554008  Nordrhein-Westfalen     Münster     Münster
# Düsseldorf     5111000  Nordrhein-Westfalen  Düsseldorf  Düsseldorf
# Gelsenkirchen  5513000  Nordrhein-Westfalen       Essen       Essen
# Herne          5916000  Nordrhein-Westfalen       Essen       Essen
# Köln           5315000  Nordrhein-Westfalen        Köln        Köln
# Mettmann       5158024  Nordrhein-Westfalen   Wuppertal  Düsseldorf
# Windeck        5382076  Nordrhein-Westfalen        Köln        Bonn
# Windeck        5382076  Nordrhein-Westfalen        Köln        Bonn
#
#                    region          district regierungsbezirk
# Ahaus           Westfalen            Borken          Münster
# Bielefeld       Westfalen         Bielefeld          Detmold
# Bocholt         Westfalen            Borken          Münster
# Düsseldorf      Rheinland        Düsseldorf       Düsseldorf
# Gelsenkirchen  Ruhrgebiet     Gelsenkirchen          Münster
# Herne          Ruhrgebiet             Herne         Arnsberg
# Köln            Rheinland              Köln             Köln
# Mettmann        Rheinland          Mettmann       Düsseldorf
# Windeck         Rheinland  Rhein-Sieg-Kreis             Köln
# Windeck         Rheinland  Rhein-Sieg-Kreis             Köln

# %% [markdown]
# ## Durchschnitt aller Schulen

# %%
# Pandas hat eine eigene Funktion, um Durchschnoittswerte zu bilden
df.F1_ausstattung.mean()
# Out:
# 3.5989515072083877

# %% [markdown]
# ### Zufriedenheit nach Regierungsbezirken

# %%
# Um zu ermitteln, in welchem Regierungsbezirk die Schulleiter*innen am zufriedensten sind, nutzen wir group_by: 
df.groupby('regierungsbezirk').mean()
# Out:
#                   F1_ausstattung
# regierungsbezirk
# Arnsberg                3.765823
# Detmold                 3.381443
# Düsseldorf              3.676647
# Köln                    3.601093
# Münster                 3.407407

# %% [markdown]
# ### Übung

# %% [markdown]
# Schreibe die jeweilige group_by - Funktion

# %%
# Zufriedenheit nach Stadt / Land (type)
df.groupby('type').mean()
# Out:
#           F1_ausstattung
# type
# Gemeinde        3.196721
# Stadt           3.633436

# %%
# Zufriedenheit nach Regionen
df.groupby('region').mean()
# Out:
#             F1_ausstattung
# region
# Rheinland         3.609231
# Ruhrgebiet        3.896970
# Westfalen         3.354260

# %%
# Zufriedenheit nach Landkreisen
df.groupby('district').mean().sort_values(by='F1_ausstattung', ascending=False)
# Out:
#                             F1_ausstattung
# district
# Krefeld                           5.000000
# Hagen                             4.857143
# Bochum                            4.681818
# Leverkusen                        4.500000
# Essen                             4.500000
# Hamm                              4.333333
# Mönchengladbach                   4.153846
# Bonn                              4.142857
# Märkischer Kreis                  4.000000
# Oberhausen                        4.000000
# Recklinghausen                    4.000000
# Bottrop                           4.000000
# Rhein-Erft-Kreis                  3.954545
# Viersen                           3.933333
# Heinsberg                         3.916667
# Mettmann                          3.904762
# Städteregion Aachen               3.900000
# Düren                             3.833333
# Hochsauerlandkreis                3.800000
# Olpe                              3.750000
# Wuppertal                         3.727273
# Bielefeld                         3.714286
# Ennepe-Ruhr-Kreis                 3.687500
# Herne                             3.666667
# Rhein-Kreis Neuss                 3.666667
# Warendorf                         3.615385
# Gütersloh                         3.600000
# Rhein-Sieg-Kreis                  3.555556
# Gelsenkirchen                     3.538462
# Dortmund                          3.529412
# Solingen                          3.500000
# Remscheid                         3.500000
# Minden-Lübbecke                   3.500000
# Duisburg                          3.400000
# Unna                              3.370370
# Euskirchen                        3.333333
# Köln                              3.327869
# Wesel                             3.250000
# Rheinisch-Bergischer Kreis        3.250000
# Lippe                             3.222222
# Münster                           3.222222
# Soest                             3.214286
# Steinfurt                         3.200000
# Kleve                             3.133333
# Borken                            3.111111
# Paderborn                         3.083333
# Herford                           3.083333
# Höxter                            3.000000
# Siegen-Wittgenstein               3.000000
# Oberbergischer Kreis              2.916667
# Düsseldorf                        2.785714
# Coesfeld                          2.533333

# %% [markdown]
# ### Übung

# %%
# Nach Schulform
df.groupby('schulform').mean().sort_values(by='F1_ausstattung', ascending=False)
# Out:
#                       F1_ausstattung
# schulform
# PRIMUS-Schule               5.000000
# Hauptschule                 4.130435
# Grundschule                 4.009174
# Förderschule                3.672414
# Sonstiges                   3.600000
# Realschule                  3.393443
# Sekundarschule              3.350000
# Gesamtschule                3.278481
# Weiterbildungskolleg        3.142857
# Gymnasium                   3.037383
# Berufskolleg                3.015873
# Privatschule                2.000000

# %% [markdown]
# Wo gibt es aus deiner Sicht die spannendsten Ergebnisse?

# %% [markdown]
# ### Übung

# %% [markdown]
# Wie findest Du heraus, wie viele Schulen eine 1 bzw. eine 6 vergeben haben?

# %%
# Wieviele Schulen sind super zufrieden (1.0)
len(df[df.F1_ausstattung == 1.0])
# Out:
# 32

# %%
# Wieviele Schulen sind super unzufrieden (6.0)
len(df[df.F1_ausstattung == 6.0])
# Out:
# 58

# %% [markdown]
# Auf zur nächsten Datenquelle:
#
# **[ >> Excel-Dokumente Notebook](06b_excel.ipynb)**
