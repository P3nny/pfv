# %% [markdown]
# # APIs

# %% [markdown]
# **API** steht für **Application Programming Interface**, auf Deutsch wörlich **"Anwendungs­programmier­schnittstelle"**.
#
# APIs im Allgemeinen finden sich in so ziemlich jeder Ecke der Software-Entwicklung, denn sie sind nötig, damit verschiedene Programme und Systeme miteinander verbunden werden und kommunizieren können.
#
# Für uns interessant sind aber hauptsächlich Web-APIs, also Anwendungsschnittstellen, die über das Internet genutzt werden. Speziell interessieren uns hier jene APIs, die auf Anfrage bestimmte Daten in Formaten wie CSV oder JSON kommunizieren.
#
# Für diese Übung wollen wir den Rhein-Pegel über eine API abrufen. Die API zu dieser Übung ist [hier](https://www.pegelonline.wsv.de/webservice/guideRestapi) dokumentiert. Da diese API die Daten im JSON-Format herausgibt, solltest du die Übung zum Thema JSON bereits gemacht haben.
#
# Der erste Schritt für uns ist, die Liste der Stationen im Rhein abzurufen. Dafür können wir die folgende URL benutzen:
#
# https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations.json?waters=RHEIN
#
# Wir können die URL in drei Komponenten unterteilen, um sie ein bisschen besser zu verstehen.
#
# - `https://www.pegelonline.wsv.de/webservices/rest-api/v2/`
#   - Dies ist die **Basis-URL** aller Anfragen an diese API. Wir können verschiedene **Endpunkte** anhängen, um verschiedene Arten von Daten abzurufen.
# - `stations.json`
#   - Dies ist der sogenannte **Endpunkt**. Damit spezifieren wir, welche Kategorie von Daten wir abrufen wollen. In diesem Fall ist er sehr kurz, aber das muss nicht immer der Fall sein.
# - `?waters=RHEIN`
#   - Dieser Teil ist die Parameterliste. Hier übergeben wir nur ein Parameter, `waters`, mit dem Wert `RHEIN`. Wir teilen der API also mit, dass wir nur an Stationen in bestimmten Gewässern interessiert sind. Grundsätzlich gibt es kein Limit für die Anzahl von Parametern die an eine API übergeben werden können.  Gleichzeitig ist dieser Teil aber auch optional. Gibt es mehrere Parameter, so werden sie in der Regel mit einem `&` voneinander getrennt.
#
# Die Trennung von Endpunkt und Parametern ist nicht immer so eindeutig wie hier, aber es ist prinzipiell hilfreich, eine URL für eine API-Anfrage auf diese Bestandteile zu untersuchen, um den Abruf besser zu verstehen.
#
# Rufe die URL nun zunächst in deinem Browser auf. Du solltest eine Menge JSON auf deinem Bildschirm sehen. Das kann erstmal etwas überfordernd sein. Vielleicht erinnerst du dich daran, dass wir in der JSON-Übung eine ganz ähnliche Datenstruktur direkt in Pandas importieren konnten. Versuchen wir das hier doch auch mal, und gucken was passiert. Praktischerweise kann man einfach direkt die URL angeben und muss die Datei nicht extra vorher herunterladen - das macht es etwas einfacher für uns.

# %%
import pandas as pd

df = pd.read_json('https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations.json?waters=RHEIN')
df
# Out:
#                                     uuid    number            shortname  \
# 0   e020e651-e422-46d3-ae28-34887c5a4a8e      3329       Konstanz-Rhein
# 1   94f6eff1-4f3f-4850-82e0-a086198e9ffd   2310010     Basel-Rheinhalle
# 2   06b978dd-8c4d-48ac-a0c8-2c16681ed281  23300130          RHEINWEILER
# 3   9da1ad2b-88db-4cbb-8132-eddfab07d5ba  23300320             BREISACH
# 4   5389b878-fad5-4f37-bb87-e6cb36b7078b  23300580                 RUST
# 5   787e5d63-61e2-48cc-acf0-633e2bf923f2  23300800            OTTENHEIM
# 6   23af9b02-5c82-4f6e-acb8-f92a06e5e4da  23300900       KEHL-KRONENHOF
# 7   b02be240-1364-4c97-8bb6-675d7d842332  23500600            IFFEZHEIM
# 8   6b774802-fcb5-49ae-8ecb-ecaf1a278b1c  23500700         PLITTERSDORF
# 9   b6c6d5c8-e2d5-4469-8dd8-fa972ef7eaea  23700200                MAXAU
# 10  88e972e1-88a0-4eb9-847c-0925e5999a46  23700500         PHILIPPSBURG
# 11  2cb8ae5b-c5c9-4fa8-bac0-bb724f2754f4  23700600               SPEYER
# 12  57090802-c51a-4d09-8340-b4453cd0e1f5  23700700             MANNHEIM
# 13  844a620f-f3b8-4b6b-8e3c-783ae2aa232a  23900200                WORMS
# 14  d28e7ed1-3317-41c5-bec6-725369ed1171  23900600  NIERSTEIN-OPPENHEIM
# 15  a37a9aa3-45e9-4d90-9df6-109f3a28a5af  25100100                MAINZ
# 16  665be0fe-5e38-43f6-8b04-02a93bdbeeb4  25100300             OESTRICH
# 17  0309cd61-90c9-470e-99d4-2ee4fb2c5f84  25300200               BINGEN
# 18  1d26e504-7f9e-480a-b52c-5932be6549ab  25700100                 KAUB
# 19  550eb7e9-172e-48e4-ae1e-d1b761b42223  25700300           SANKT GOAR
# 20  2ff6379d-d168-4022-8da0-16846d45ef9b  25700500              BOPPARD
# 21  d6dc44d1-63ac-4871-b175-60ac4040069a  25700600             BRAUBACH
# 22  4c7d796a-39f2-4f26-97a9-3aad01713e29  25900700              KOBLENZ
# 23  dc407f1e-e25f-4995-9feb-5bacc8658149  27100370        Neuwied Stadt
# 24  5735892a-ec65-4b29-97c5-50939aa9584e  27100400            ANDERNACH
# 25  b45359df-c020-4314-adb1-d1921db642da  27100700           OBERWINTER
# 26  593647aa-9fea-43ec-a7d6-6476a76ae868   2710080                 BONN
# 27  a6ee8177-107b-47dd-bcfd-30960ccc6e9c   2730010                 KÖLN
# 28  8f7e5f92-1153-4f93-acba-ca48670c8ca9   2750010           DÜSSELDORF
# 29  c0f51e35-d0e8-4318-afaf-c5fcbc29f4c1   2770010     DUISBURG-RUHRORT
# 30  f33c3cc9-dc4b-4b77-baa9-5a5f10704398   2770040                WESEL
# 31  2f025389-fac8-4557-94d3-7d0428878c86   2790010                 REES
# 32  9598e4cb-0849-401e-bba0-689234b27644   2790020             EMMERICH
#
#                longname       km                            agency  \
# 0        KONSTANZ-RHEIN    0.475      REGIERUNGSPRÄSIDIUM FREIBURG
# 1      BASEL-RHEINHALLE  165.900              BUNDESAMT FÜR UMWELT
# 2           RHEINWEILER  186.178                     WSA OBERRHEIN
# 3              BREISACH  227.550                     WSA OBERRHEIN
# 4                  RUST  254.153                     WSA OBERRHEIN
# 5             OTTENHEIM  270.593                     WSA OBERRHEIN
# 6        KEHL-KRONENHOF  292.250                     WSA OBERRHEIN
# 7             IFFEZHEIM  336.200                     WSA OBERRHEIN
# 8          PLITTERSDORF  340.215                     WSA OBERRHEIN
# 9                 MAXAU  362.327                     WSA OBERRHEIN
# 10         PHILIPPSBURG  389.330                     WSA OBERRHEIN
# 11               SPEYER  400.600                     WSA OBERRHEIN
# 12             MANNHEIM  424.733                     WSA OBERRHEIN
# 13                WORMS  443.400                     WSA OBERRHEIN
# 14  NIERSTEIN-OPPENHEIM  480.606                     WSA OBERRHEIN
# 15                MAINZ  498.270                         WSA RHEIN
# 16             OESTRICH  518.080                         WSA RHEIN
# 17               BINGEN  528.360                         WSA RHEIN
# 18                 KAUB  546.300                         WSA RHEIN
# 19           SANKT GOAR  556.430                         WSA RHEIN
# 20              BOPPARD  570.450                         WSA RHEIN
# 21             BRAUBACH  579.980                         WSA RHEIN
# 22              KOBLENZ  591.490                         WSA RHEIN
# 23        NEUWIED STADT  608.040  DEICHINFORMATIONSZENTRUM NEUWIED
# 24            ANDERNACH  613.780                         WSA RHEIN
# 25           OBERWINTER  638.190                         WSA RHEIN
# 26                 BONN  654.800                         WSA RHEIN
# 27                 KÖLN  688.000                         WSA RHEIN
# 28           DÜSSELDORF  744.200                         WSA RHEIN
# 29     DUISBURG-RUHRORT  780.800                         WSA RHEIN
# 30                WESEL  814.000                         WSA RHEIN
# 31                 REES  837.400                         WSA RHEIN
# 32             EMMERICH  851.900                         WSA RHEIN
#
#                                           water  longitude   latitude
# 0   {'shortname': 'RHEIN', 'longname': 'RHEIN'}        NaN        NaN
# 1   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.616666  47.559486
# 2   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.529275  47.711059
# 3   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.572570  48.043210
# 4   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.707970  48.269172
# 5   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.732657  48.384644
# 6   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.807692  48.563320
# 7   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.116902  48.852149
# 8   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.135927  48.885967
# 9   {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.305564  49.038977
# 10  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.428827  49.255274
# 11  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.448705  49.323807
# 12  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.455165  49.483940
# 13  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.377519  49.631837
# 14  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.352376  49.864981
# 15  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.275319  50.003995
# 16  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   8.030048  50.002866
# 17  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.899668  49.970342
# 18  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.764962  50.085438
# 19  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.712615  50.152557
# 20  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.592132  50.232914
# 21  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.645667  50.270501
# 22  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.604741  50.358639
# 23  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.457453  50.424277
# 24  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.392056  50.443390
# 25  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.214981  50.601061
# 26  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   7.108045  50.736398
# 27  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   6.963300  50.936949
# 28  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   6.769891  51.225498
# 29  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   6.727927  51.455345
# 30  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   6.606820  51.646143
# 31  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   6.395692  51.756953
# 32  {'shortname': 'RHEIN', 'longname': 'RHEIN'}   6.245594  51.829252

# %% [markdown]
# Wir können sehen, dass der Datenimport bis auf die `water`-Spalte ziemlich gut funktioniert hat. Glücklicherweise haben wir das Gewässer bereits beim Abruf spezifiziert, sodass wir uns darüber keine Sorgen machen müssen.
#
# Aus dieser Stationsliste können wir aber noch keinen Wasserstand auslesen. Dafür müssen wir auf die Daten einer bestimmten Station zugreifen. Es gibt eine Station in Köln, rufen wir doch für diese mal den aktuellen Wasserstand ab. Die Dokumentation erklärt uns, dass wir dafür eine URL wie die folgende nutzen können:
#
# https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations/KÖLN/W/currentmeasurement.json
#
# Schau dir die Daten wieder zuerst in deinem Browser an.
#
# Wie du siehst, findet sich hier nur ein einzelnes Objekt, statt wie zuvor eine Liste von Objekten. Das ist einfacher zu lesen und verstehen, aber können wir das in Pandas einlesen?

# %%
import pandas as pd

pd.read_json('https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations/BONN/W/currentmeasurement.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-d54678949b27> in <module>
#       1 import pandas as pd
#       2
# ----> 3 pd.read_json('https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations/BONN/W/currentmeasurement.json')
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --> 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\io\json\_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --> 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == "frame":
# --> 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == "series" or obj is None:
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     884
#     885         else:
# --> 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1116
#    1117         if orient == "columns":
# -> 1118             self.obj = DataFrame(
#    1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# c:\users\jhoeke\git\pfv\myvenv\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     385
#     386         if not indexes and not raw_lengths:
# --> 387             raise ValueError("If using all scalar values, you must pass an index")
#     388
#     389         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %% [markdown]
# Uff. Pandas gibt uns eine Fehlermeldung. Aber irgendwie wäre ein Dataframe ja auch gar nicht so richtig praktisch, um mit diesem Datensatz weiter zu arbeiten. Eine Tabelle mit nur einer Zeile? Dabei hat Python doch bereits einen Datentyp, der genau diese Form hat, nämlich das `dict`. Wir erinnern uns an `json.load` aus der JSON-Übung.
#
# Leider müssen wir uns jetzt um das Herunterladen der Daten selber kümmern. Dafür können wir zum Beispiel das populäre Paket `requests` nutzen.

# %%
import requests

response = requests.get('https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations/KÖLN/W/currentmeasurement.json')

water_level = response.json()  # requests kann uns sogar direkt das JSON parsen!
water_level
# Out:
# {'timestamp': '2020-09-06T15:45:00+02:00',
#  'value': 235.0,
#  'trend': -1,
#  'stateMnwMhw': 'normal',
#  'stateNswHsw': 'normal'}

# %% [markdown]
# Hervorragend! Wenn du dein Verständnis prüfen willst, versuche doch mal, den aktuellen Wasserstand eines anderen Flusses von der API abzurufen. Wenn du eine Herausvorderung suchst, kannst du versuchen, eine Zeitreihe einer Station deiner Wahl mit Pandas abzurufen und zu plotten, oder mal eine der folgenden APIs zu erkunden: https://github.com/public-apis/public-apis

# %%
import pandas as pd

df = pd.read_json('https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations/K%C3%96LN/W/measurements.json?start=P14D')

df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.rename(columns={'value': 'Wasserstand', 'timestamp': 'Datum'})

df.plot(x='Datum', ylabel='cm')
# Out:
# <AxesSubplot:xlabel='Datum', ylabel='cm'>

# %%
# Cat facts!

import random

import requests

facts = requests.get('https://cat-fact.herokuapp.com/facts').json()
random.choice(facts['all'])['text']
# Out:
# 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.'

# %% [markdown]
# ## URL Encoding
# Manchmal möchte man Zeichen in URLs unterbringen, die problematisch sein können - entweder, weil sie schon ihre eigene Bedeutung in URLs zugeordnet haben, wie zum Beispiel `/`, `?`, weil sie nicht im ASCII-Zeichensatz enthalten sind, oder weil sie aus anderen Gründen unzulässig sind (z. B. Leerzeichen). Dazu gehören auch immer Umlaute.
#
# Um diese Zeichen trotzdem übertragen zu können, wird in der Regel das sogenannte Prozent-Encoding verwendet. Die `requests`-Bibliothek macht das in der Regel automatisch für dich, Pandas jedoch nicht. Wenn du auf einen solchen Fehler triffst, kannst du folgende Funktion verwenden:

# %%
from urllib.parse import quote

quote('KÖLN')
# Out:
# 'K%C3%96LN'

# %% [markdown]
# ## Parameter mit Requests
# Wenn man mit APIs arbeitet, will man oft verschieden Kombinationen von Parametern ausprobieren oder vielleicht sogar programmatisch die Werte der Parameter zuweisen können. Um das einfacher zu machen, hier ein kleiner Trick:

# %%
import requests

# Parameter können vorher als 'dict' angelegt werden
parameters = {
    'foo': 'bar',
    'flavor': 'vanilla',
}

# httpbin.org ist ein Test-Service für Web-Anfragen
# Er antwortet mit Informationen über die Anfrage, z. B. die URL
response = requests.get('https://httpbin.org/get', params=parameters).json()
print('Resultierende URL:', response['url'])
# Out:
# Resultierende URL: https://httpbin.org/get?foo=bar&flavor=vanilla

# %% [markdown]
# Wir sehen: Parameter werden korrekt mit `?` und `&` an die URL angehängt.

# %% [markdown]
# ## Datenstrukturen in Python

# %% [markdown]
# Nicht immer können oder wollen wir Pandas nutzen, um mit unseren Daten zu arbeiten. Hier wollen wir ein paar Möglichkeiten kennenlernen, um mit Datenstrukturen wie `dict` und `list` in Python umzugehen. Wenn du eine JSON-API erforschen willst, kann dir diese Sektion dabei helfen.
#
# Listen und Dictionaries sind die beiden häufigsten Wege, mehrere Werte in einer Sammlung zusammenzufassen. Daher gibt es auch viele Möglichkeiten, sie zu verarbeiten und auf die Werte, die sich darin befinden, zuzugreifen. Genau so kann man neue Listen und Dictionaries auf vielen Wegen erzeugen und mit Werten befüllen. Wir wollen uns hier aber hauptsächlich auf das Auslesen konzentrieren.
#
# Beginnen wir mit ein paar Dingen, die wir mit Listen tun können:

# %%
words = [
    "eine",
    "liste",
    "fantastischer",
    "wörtern",
    "zum",
    "testen"
]

numbers = [
    3,
    -14,
    800,
    44,
]

# %%
# Die 'len'-Funktion gibt die Größe von Sammlungen wie list und dict zurück
print("Anzahl der Wörter:", len(words))

# Übrigens: Auch die Länge von Strings können wir damit herausfinden
print("Länge des Worts 'Wort':", len("Wort"))

# Um einen bestimmten Eintrag aus einer Liste abzurufen, werden wie bei dict eckige Klammern benutzt
# Computer fangen immer bei 0 an zu zählen!
print("Das erste Wort:", words[0])

# Wir können auch anders herum
print("Das letzte Wort:", words[-1])

# Mit 'sum' können wir eine Liste von Zahlen summieren
print("Summe der Zahlen:", sum(numbers))

# Was ist die kleinste/größte Zahl? 'min' und 'max' geben Auskunft
print("Kleinste Zahl:", min(numbers))

# Pro-Tip: Wir können 'min' und 'max' auch eine Funktion geben, die es für die Kalkulation benutzen soll
# Die Funktion wird auf jeden Wert in der Liste angewandt und das Ergebnis für den Vergleich benutzt
print("Letztes Wort nach Alphabet sortiert:", max(words))
print("Längstes Wort:", max(words, key=len))

# Das gleiche funktioniert übrigens auch mit 'sorted', was zum sortieren von Listen genutzt wird
print(sorted(words))
print(sorted(words, key=len))

# Wir können auch unsere eigenen Funktionen übergeben

def distance_from_10(number):
    return abs(10 - number)  # 'abs' berechnet den Betrag einer Zahl

print("Zahl am nächsten zu 10:", min(numbers, key=distance_from_10))

# Spiele gerne ein bisschen mit diesen Funktionen herum. Du kannst dir eigene Listen anlegen.
# Out:
# Anzahl der Wörter: 6
# Länge des Worts 'Wort': 4
# Das erste Wort: eine
# Das letzte Wort: testen
# Summe der Zahlen: 833
# Kleinste Zahl: -14
# Letztes Wort nach Alphabet sortiert: zum
# Längstes Wort: fantastischer
# ['eine', 'fantastischer', 'liste', 'testen', 'wörtern', 'zum']
# ['zum', 'eine', 'liste', 'testen', 'wörtern', 'fantastischer']
# Zahl am nächsten zu 10: 3

# %% [markdown]
# Puh. Das ist schon ziemlich kompliziert... Wenn du nicht alles im Detail verstanden hast, ist das nicht so schlimm.
#
# Wichtig ist:
# - Wir können diese Funktionen nutzen, um aus Listen Informationen zu ziehen
# - Wir können Funktionen als Parameter an diese (und andere) Funktionen übergeben, um deren Verhalten zu modifizieren
#
# Bevor wir mehr daraus machen, sollten wir uns noch ein bisschen mit der Navigation durch verschachtelte Strukturen bekannt machen.
#
# Betrachten wir die Station in Bonn mal etwas genauer. Die API-Dokumentation sagt, dass wir einige Informationen zu der Station mit abrufen können, wenn wir entsprechende Parameter mit angeben:

# %%
import requests
import json

url = 'https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations/BONN.json'

parameters = {
    'includeTimeseries': 'true',
    'includeCurrentMeasurement': 'true',
}

bonn = requests.get(url, params=parameters).json()

# Kleiner Trick, um die Ausgabe von komplexen dicts etwas lesbarer zu machen
print(json.dumps(bonn, indent=4, ensure_ascii=False))
# Out:
# {
#     "uuid": "593647aa-9fea-43ec-a7d6-6476a76ae868",
#     "number": "2710080",
#     "shortname": "BONN",
#     "longname": "BONN",
#     "km": 654.8,
#     "agency": "WSA RHEIN",
#     "longitude": 7.108045442593696,
#     "latitude": 50.7363979694278,
#     "water": {
#         "shortname": "RHEIN",
#         "longname": "RHEIN"
#     },
#     "timeseries": [
#         {
#             "shortname": "W",
#             "longname": "WASSERSTAND ROHDATEN",
#             "unit": "cm",
#             "equidistance": 15,
#             "currentMeasurement": {
#                 "timestamp": "2020-09-06T15:45:00+02:00",
#                 "value": 231.0,
#                 "trend": -1,
#                 "stateMnwMhw": "normal",
#                 "stateNswHsw": "unknown"
#             },
#             "gaugeZero": {
#                 "unit": "m. ü. NHN",
#                 "value": 42.713,
#                 "validFrom": "2019-11-01"
#             }
#         },
#         {
#             "shortname": "Q",
#             "longname": "ABFLUSS_ROHDATEN",
#             "unit": "m³/s",
#             "equidistance": 15,
#             "currentMeasurement": {
#                 "timestamp": "2020-09-06T12:45:00+02:00",
#                 "value": 1450.0,
#                 "trend": 0
#             }
#         }
#     ]
# }

# %% [markdown]
# Angenommen uns interessiert der aktuelle Wasserstand. Wie kommen wir da überhaupt ran?

# %%
timeseries = bonn['timeseries']  # Zugriff auf das 'bonn'-dict Anhand des Schlüssels
water_level = timeseries[0]  # 'timeseries' ist eine Liste, daher rufen wir Werte per Index ab
current_measurement = water_level['currentMeasurement']  # Der erste Eintrag aus der timeseries ist wieder ein dict
value = current_measurement['value']  # Und schließlich haben wir den Wert, den wir suchen

print("Wasserstand:", value)

# Das ganze geht auch in einer Zeile
print("Wasserstand:", bonn['timeseries'][0]['currentMeasurement']['value'])

# Übung: Finde die Abflussrate und Null-Stand auf ähnlichem Wege heraus
# Out:
# Wasserstand: 231.0
# Wasserstand: 231.0

# %% [markdown]
# Wir haben jetzt bereits die Werkzeuge in der Hand, um die Rhein-Station mit dem höchsten und niedrigsten aktuell gemessenen Wasserstand herauszufinden!
#
# Der Abruf https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations.json?waters=RHEIN&includeTimeseries=true&includeCurrentMeasurement=true enhält eine Liste aller Stationen im Format des letzten Beispiels.

# %%
import requests

url = 'https://www.pegelonline.wsv.de/webservices/rest-api/v2/stations.json'

parameters = {
    'waters': 'RHEIN',
    'includeTimeseries': 'true',
    'includeCurrentMeasurement': 'true',
}

stations = requests.get(url, params=parameters).json()

def get_waterlevel(station):
    # Der Wasserstand scheint immer der erste Eintrag in den timeseries zu sein
    return station['timeseries'][0]['currentMeasurement']['value']

highest_station = max(stations, key=get_waterlevel)
#print(json.dumps(highest_station, indent=4, ensure_ascii=False))

name = highest_station['shortname']
water_level = get_waterlevel(highest_station)
print(name, water_level)
# Out:
# Basel-Rheinhalle 565.0
